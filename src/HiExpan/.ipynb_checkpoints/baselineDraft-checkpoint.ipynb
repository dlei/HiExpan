# %%
import util
import set_expan
import time
import pickle

load_pickle_flag = True
FLAGS_USE_TYPE = True
data = "dblpv2"
folder = '../../data/'+data+'/intermediate/'


print("=== Start loading all files ...... ===")
print("load_from_pickle")
pickle_file = '../../data/' + data + '/intermediate/all_data.pickle'
with open(pickle_file, "rb") as fin:
    [eid2ename, ename2eid, eid2patterns, pattern2eids, eidAndPattern2strength, eid2types, type2eids,
     eidAndType2strength, eid2embed, embed_matrix, eid2rank, rank2eid, embed_matrix_array, skipgramsByEidPairMap,
     eidPairsBySkipgramMap, weightByEidPairAndSkipgramMap] = pickle.load(fin)
print("=== Finish loading all files. HaHaHa ===")
# Out:
# === Start loading all files ...... ===
# load_from_pickle
# === Finish loading all files. HaHaHa ===

# %%
from tree_node import TreeNode
from collections import defaultdict

level2max_children = {-1:10, 0:15, 1:5, 2:1e9, 3:1e9, 4:1e9, 5:1e9}
level2reference_edges = defaultdict(list)
userInput = [
  ["ROOT", -1, ["machine learning", "data mining", "information retrieval"]],

  ["machine learning", 0, ["supervised machine learning", "unsupervised learning", "reinforcement learning"]],
  ["data mining", 0, ["pattern mining", "graph mining", "web mining", "text mining"]],
  ["information retrieval", 0, ["document retrieval", "query processing", "relevance feedback"]],
]

# generate reference edges
rootNode = None
ename2treeNode = {}
for i, node in enumerate(userInput):
  if i == 0: ## ROOT
    rootNode = TreeNode(parent=None, level=-1, eid=-1, ename="ROOT", isUserProvided=True, confidence_score=0.0,
                        max_children=level2max_children[-1])
    ename2treeNode["ROOT"] = rootNode
    for children in node[2]:
      newNode = TreeNode(parent=rootNode, level=0, eid=ename2eid[children], ename=children, isUserProvided=True,
                         confidence_score=0.0, max_children=level2max_children[0])
      ename2treeNode[children] = newNode
      rootNode.addChildren([newNode])
  else:
    ename = node[0]
    eid = ename2eid[ename]  # assume user supervision is an entity mention in entity2id.txt
    level = node[1]
    childrens = node[2]
    if ename in ename2treeNode: # existing node
      parent_treeNode = ename2treeNode[ename]
      for children in childrens:
        newNode = TreeNode(parent=parent_treeNode, level=parent_treeNode.level+1, eid=ename2eid[children],
                           ename=children, isUserProvided=True, confidence_score=0.0,
                           max_children=level2max_children[parent_treeNode.level+1])
        ename2treeNode[children] = newNode
        parent_treeNode.addChildren([newNode])
        level2reference_edges[parent_treeNode.level].append((parent_treeNode.eid, newNode.eid))
    else: # not existing node
      print("[ERROR] disconnected tree node: %s" % node)
    
print(rootNode.children)
FLAGS_INITIAL_EDGE = 1
print(FLAGS_INITIAL_EDGE)

def obtainReferenceEdges(targetNode):
  reference_edges = []
  ## Add 1) edges in user guidance and 2) first FLAGS_INITIAL_EDGE edge under each sibling nodes as
  # reference edges
  for sibling in targetNode.parent.children:
    print(sibling)
    cnt = 0
    for cousin in sibling.children:
      print(cousin)
      if cousin.isUserProvided and sibling.isUserProvided:
        reference_edges.append((sibling.eid, cousin.eid))
      else:
        reference_edges.append((sibling.eid, cousin.eid))
        cnt += 1
        if cnt >= FLAGS_INITIAL_EDGE:
          break
  return reference_edges


reference_edges = obtainReferenceEdges(rootNode.children[0])
# Out:
# 0
# 1
# 2
# 3
# [<tree_node.TreeNode object at 0x7f1172423e10>, <tree_node.TreeNode object at 0x7f1172423e48>, <tree_node.TreeNode object at 0x7f1172423e80>]
# 1
# machine learning (eid=8723,log_prob=0.000000,parent=ROOT)
# supervised machine learning (eid=15042,log_prob=0.000000,parent=machine learning)
# unsupervised learning (eid=16106,log_prob=0.000000,parent=machine learning)
# reinforcement learning (eid=12815,log_prob=0.000000,parent=machine learning)
# data mining (eid=3362,log_prob=0.000000,parent=ROOT)
# pattern mining (eid=11186,log_prob=0.000000,parent=data mining)
# graph mining (eid=6257,log_prob=0.000000,parent=data mining)
# web mining (eid=16714,log_prob=0.000000,parent=data mining)
# text mining (eid=15448,log_prob=0.000000,parent=data mining)
# information retrieval (eid=7348,log_prob=0.000000,parent=ROOT)
# document retrieval (eid=4144,log_prob=0.000000,parent=information retrieval)
# query processing (eid=12403,log_prob=0.000000,parent=information retrieval)
# relevance feedback (eid=12886,log_prob=0.000000,parent=information retrieval)

# %%
# userInput = ["functional sites", "genotype data", "structural motifs"]
userInput = ["machine learning", "data mining", "information retrieval"]
seedEidsWithConfidence = [(ename2eid[ele.lower()], 0.0) for ele in userInput]

level2Input = ["supervised machine learning", "unsupervised learning", "reinforcement learning", 
               "pattern mining", "graph mining", "web mining", "text mining", 
              "document retrieval", "query processing", "relevance feedback"]

level2InputSeeds = [(ename2eid[ele.lower()], 0.0) for ele in level2Input]


print(seedEidsWithConfidence)
negativeSeedEids = set()

def runSetExpan(seedEidsWithConfidence):
    expandedEidsWithConfidence = set_expan.setExpan(
        seedEidsWithConfidence=seedEidsWithConfidence,
        negativeSeedEids=negativeSeedEids,
        eid2patterns=eid2patterns,
        pattern2eids=pattern2eids,
        eidAndPattern2strength=eidAndPattern2strength,
        eid2types=eid2types,
        type2eids=type2eids,
        eidAndType2strength=eidAndType2strength,
        eid2ename=eid2ename,
        eid2embed=eid2embed,
        source_weights={"sg":1.0, "tp":5.0, "eb":5.0},
        use_embed=True,
        use_type=True,
        FLAGS_VERBOSE=True,
        FLAGS_DEBUG=True
    )
    print(expandedEidsWithConfidence)
    for ele in expandedEidsWithConfidence:
      print("eid=", ele[0], "ename=", eid2ename[ele[0]], "confidence_score=", ele[1])

    
    return expandedEidsWithConfidence



expandedParent = runSetExpan(seedEidsWithConfidence)
expandedChildren = runSetExpan(level2InputSeeds)
# Out:
# [(8723, 0.0), (3362, 0.0), (7348, 0.0)]
# Seed set:
# 8723 machine learning
# 3362 data mining
# 7348 information retrieval
# [INFO] Start SetExpan
# [INFO] CoreTypes of the seedsEids at iteration 1 is ['information technology', 'natural language processing application', 'natural language application', 'natural language processing task', 'application domain']
# [INFO] Finish context feature selection using time 0.05844736099243164 seconds
# Start ranking ensemble at iteration 1: Ensemble batch 0 using time 0.8016178607940674 [INFO] Candidate entities matched by skipgrams = 1019
# [INFO] Candidate entities that matched by either skipgrams or types = 6797
# End ranking ensemble at iteration 1
# Totally using time 2.1335973739624023 seconds
# ========================================
# [INFO] Skipgram Top Results: [['pattern recognition', 1.0], ['artificial intelligence', 0.5], ['image processing', 0.3333333333333333], ['natural language processing', 0.25], ['neural networks', 0.2], ['computational biology', 0.16666666666666666], ['data analysis', 0.14285714285714285], ['signal processing', 0.125], ['data management', 0.1111111111111111], ['knowledge discovery', 0.1], ['face recognition', 0.09090909090909091], ['web search', 0.08333333333333333], ['text categorization', 0.07692307692307693], ['text mining', 0.07142857142857142], ['molecular biology', 0.06666666666666667], ['medical imaging', 0.0625], ['multi-agent systems', 0.058823529411764705], ['social networks', 0.05555555555555555], ['information extraction', 0.05263157894736842], ['wireless communications', 0.05], ['machine vision', 0.047619047619047616], ['knowledge discovery and data mining', 0.045454545454545456], ['computational linguistics', 0.043478260869565216], ['active learning', 0.041666666666666664], ['search engines', 0.04], ['recent years', 0.038461538461538464], ['image analysis', 0.037037037037037035], ['knowledge representation', 0.03571428571428571], ['social network analysis', 0.034482758620689655], ['ai planning', 0.03333333333333333]]
# ========================================
# [INFO] Type Top Results: [['artificial intelligence', 0.8703962400948273], ['pattern recognition', 0.6210095979189539], ['information systems', 0.5620491889202864], ['human-computer interaction', 0.5532869612535904], ['image processing', 0.4988487538296751], ['computational linguistics', 0.49170714448755914], ['biomedical research', 0.48962041844402315], ['text categorization', 0.4882837403443381], ['software engineering', 0.48590339848689085], ['expert systems', 0.4687398205073905], ['text classification', 0.46429283606903293], ['systems biology', 0.45631355222582876], ['text mining', 0.4557729027746921], ['molecular biology', 0.4555347054952147], ['cognitive science', 0.4434548612018474], ['knowledge discovery', 0.44183543664556313], ['information technology', 0.4263871034375952], ['machine translation', 0.40842773379525493], ['computational biology', 0.3957472689311017], ['social science', 0.3893280990000434], ['world wide web', 0.38805632497632214], ['computational geometry', 0.3864205159472407], ['natural language processing', 0.3783267076544604], ['signal processing', 0.3713327964098154], ['graph theory', 0.3681003174801794], ['knowledge engineering', 0.3624014638601178], ['information science', 0.35839663328443666], ['drug discovery', 0.35509562692350216], ['image analysis', 0.3523221130217428], ['decision theory', 0.3519715326625754], ['complex systems', 0.3517042124836848], ['ai research', 0.3498310815527046], ['information theory', 0.34683934833673813], ['on-line analytical processing', 0.33971645109097237], ['cognitive neuroscience', 0.3334306102968224], ['speech recognition', 0.3306040329055847], ['data analysis', 0.3239483744699699], ['life sciences', 0.3230824303293117], ['knowledge representation', 0.3208033965331462], ['human computer interaction', 0.3190718757940521], ['automated reasoning', 0.3160341579511187], ['image retrieval', 0.31482102691948843], ['computational methods', 0.3140071173134009], ['control theory', 0.31280266158473946], ['case-based reasoning', 0.31152792518195493], ['geographic information systems', 0.3093660556698336], ['database technology', 0.3073564613821912], ['game theory', 0.29758836303989206], ['cognitive psychology', 0.29615047797700184], ['social media', 0.29324846848846614]]
# ========================================
# [INFO] Embedding Top Results: [['web mining', 2.5753928646838258], ['opinion mining', 2.5188286890196605], ['social network analysis', 2.517250523079998], ['natural language processing', 2.511705861733356], ['computational linguistics', 2.5041450242124004], ['text mining', 2.4833233672236545], ['software engineering', 2.47875235216848], ['web usage mining', 2.473495877062849], ['music information retrieval', 2.467790722537322], ['knowledge discovery', 2.453357983230487], ['soft computing', 2.443566408532393], ['operations research', 2.4424997964394337], ['knowledge management', 2.4236795681620005], ['document classification', 2.421001534849834], ['machine learning and data mining', 2.4178071511777035], ['text retrieval', 2.4149710728346037], ['information visualization', 2.414092960279592], ['multimedia information retrieval', 2.412754807523185], ['knowledge engineering', 2.412473019648333], ['network analysis', 2.410870737175574], ['text processing', 2.4076837797255637], ['information extraction', 2.406879002808709], ['knowledge discovery and data mining', 2.40685595982113], ['sentiment analysis', 2.4046920410652026], ['automated reasoning', 2.395522596328681], ['document analysis', 2.39486582868805], ['user modeling', 2.389165489144287], ['bioinformatics research', 2.384540283078863], ['spatial data mining', 2.380607052104369], ['decision analysis', 2.3785186238614204], ['computational intelligence', 2.3773706359616615], ['information integration', 2.3741835002381535], ['text clustering', 2.368033011629285], ['text classification', 2.3661406434452417], ['multimedia retrieval', 2.3659603179101496], ['exploratory data analysis', 2.3643145792118045], ['data exploration', 2.3629136295935664], ['ai techniques', 2.3606064598396674], ['social science', 2.3590532718429276], ['medical informatics', 2.3557289465059807], ['recommendation systems', 2.353923122629922], ['information filtering', 2.34937064597949], ['engineering design', 2.3457673533481187], ['human computer interaction', 2.345276226286172], ['medical applications', 2.3433238417670683], ['text analysis', 2.342820374153014], ['text summarization', 2.341094094289385], ['data cleaning', 2.3342927253861023], ['ai planning', 2.3336008077788106], ['image understanding', 2.333600649404834]]
# ========================================
# Add entity artificial intelligence with confidence score 0.0
# Add entity web mining with confidence score -0.031026913924
# Add entity pattern recognition with confidence score 0.0
# Add entity opinion mining with confidence score -0.144484056116
# Add entity computational linguistics with confidence score -0.123208549321
# [INFO] Finish SetExpan for one set
# Expanded set:
# 8723 machine learning 0.0
# 3362 data mining 0.0
# 7348 information retrieval 0.0
# 697 artificial intelligence 0.0
# 16714 web mining -0.031026913924
# 11187 pattern recognition 0.0
# 10714 opinion mining -0.144484056116
# 2603 computational linguistics -0.123208549321
# [[697, 0.0], [16714, -0.031026913923969168], [11187, 0.0], [10714, -0.14448405611551984], [2603, -0.12320854932057874]]
# eid= 697 ename= artificial intelligence confidence_score= 0.0
# eid= 16714 ename= web mining confidence_score= -0.031026913924
# eid= 11187 ename= pattern recognition confidence_score= 0.0
# eid= 10714 ename= opinion mining confidence_score= -0.144484056116
# eid= 2603 ename= computational linguistics confidence_score= -0.123208549321
# Seed set:
# 15042 supervised machine learning
# 16106 unsupervised learning
# 12815 reinforcement learning
# 11186 pattern mining
# 6257 graph mining
# 16714 web mining
# 15448 text mining
# 4144 document retrieval
# 12403 query processing
# 12886 relevance feedback
# [INFO] Start SetExpan
# [INFO] CoreTypes of the seedsEids at iteration 1 is ['common supplementary method', 'classical datum mining problem', 'database heterogeneity issue', 'staff service', 'p2p application']
# [INFO] Finish context feature selection using time 0.03258252143859863 seconds
# Start ranking ensemble at iteration 1: Ensemble batch 0 using time 2.3635644912719727 [INFO] Candidate entities matched by skipgrams = 1209
# [INFO] Candidate entities that matched by either skipgrams or types = 2114
# End ranking ensemble at iteration 1
# Totally using time 3.7396247386932373 seconds
# ========================================
# [INFO] Skipgram Top Results: [['data mining', 1.0], ['pattern recognition', 0.5], ['machine learning', 0.3333333333333333], ['information retrieval', 0.25], ['natural language processing', 0.2], ['knowledge discovery', 0.16666666666666666], ['knowledge management', 0.14285714285714285], ['semidefinite programming', 0.125], ['image retrieval', 0.1111111111111111], ['scene understanding', 0.1], ['natural language', 0.09090909090909091], ['social networks', 0.08333333333333333], ['liver disease', 0.07692307692307693], ['communication complexity', 0.07142857142857142], ['person re-identification', 0.06666666666666667], ['data warehousing', 0.0625], ['text classification', 0.058823529411764705], ['data stream mining', 0.05555555555555555], ['web search', 0.05263157894736842], ['dimension reduction', 0.05], ['speech recognition', 0.047619047619047616], ['data management', 0.045454545454545456], ['clustering algorithm', 0.043478260869565216], ['recommender systems', 0.041666666666666664], ['machine vision', 0.04], ['genetic algorithm', 0.038461538461538464], ['question answering', 0.037037037037037035], ['combinatorial optimization', 0.03571428571428571], ['data analysis', 0.034482758620689655], ['object detection', 0.03333333333333333]]
# ========================================
# [INFO] Type Top Results: [['query expansion', 0.3505558067317821], ['mobile robotics', 0.34905331306962684], ['statistical pattern recognition', 0.3448396182798496], ['robot control', 0.34377078202188205], ['image retrieval', 0.32951805351453073], ['functional genomics', 0.3196578075835942], ['document clustering', 0.3171328490007007], ['active learning', 0.3120963028146693], ['image analysis', 0.3016812700457221], ['text classification', 0.3004806092433403], ['protein structure prediction', 0.30035823552118557], ['robot navigation', 0.29803581240835225], ['text categorization', 0.29716812463652464], ['biological networks', 0.2962957392319021], ['activity recognition', 0.2947143819233185], ['planning problems', 0.2912239065962682], ['microarray experiments', 0.28994016490601093], ['information retrieval', 0.28909877801006967], ['association rule mining', 0.288122180760781], ['gait recognition', 0.2879785416827342], ['multimedia services', 0.27370293691496345], ['gene function prediction', 0.273022794003585], ['depth images', 0.25355483633419607], ['handwriting recognition', 0.2534538586480594], ['semi-supervised learning', 0.2509945368339799], ['target tracking', 0.24612964559206174], ['adaptive control', 0.24516288145033716], ['multimedia traffic', 0.24239626083279872], ['foreground detection', 0.24209751857022407], ['simulated annealing', 0.24202717147567013], ['object tracking', 0.23997700134288116], ['association rules', 0.23275486912378063], ['logistic regression', 0.22949874738704318], ['rfid systems', 0.22612208833634073], ['uncertain knowledge', 0.22397268518746194], ['self-organizing map', 0.2224027959318731], ['frequent patterns', 0.21996772360551328], ['bayesian learning', 0.21748635743315425], ['traffic flow forecasting', 0.2136893447015792], ['financial time series forecasting', 0.20774555157967664], ['expression recognition', 0.2068105414995301], ['online social networks', 0.20641088385470968], ['neural network model', 0.2056776170815885], ['image search', 0.20476214506757198], ['combinatorial auctions', 0.20079206078486242], ['protein function prediction', 0.19940822380296702], ['parallel processing', 0.19684746062720224], ['query suggestion', 0.19544319142752978], ['protein structures', 0.1935680743859424], ['data integration', 0.18951929211333934]]
# ========================================
# [INFO] Embedding Top Results: [['text clustering', 8.215895794355507], ['document classification', 8.145754277743546], ['web usage mining', 8.09103149064708], ['record linkage', 8.043891661175806], ['rule discovery', 8.035142721170514], ['text summarization', 7.99931681037009], ['text retrieval', 7.975790807744942], ['document analysis', 7.967370570230624], ['multi-document summarization', 7.95140567231058], ['grammatical inference', 7.941366474687259], ['document clustering', 7.9406475304795405], ['data cleaning', 7.927496568633374], ['relation extraction', 7.925365292302848], ['sequential pattern mining', 7.922195521929205], ['document categorization', 7.9089233220125035], ['statistical machine learning', 7.90341055555153], ['subgroup discovery', 7.894446661898086], ['user modeling', 7.888495145757061], ['sequence labeling', 7.8870982020314555], ['association mining', 7.884445426669796], ['association rule discovery', 7.87991144504876], ['anomaly detection', 7.8766260399739165], ['video summarization', 7.86960195349787], ['image annotation', 7.8686083877762565], ['statistical learning', 7.866111306987165], ['survival analysis', 7.863718015515708], ['sequence mining', 7.861981532404656], ['pattern discovery', 7.857073184661427], ['outlier detection', 7.852592192619213], ['social network analysis', 7.849222574453399], ['image search', 7.8344571955184605], ['sentiment classification', 7.832156835631565], ['spam filtering', 7.831144510314538], ['document summarization', 7.831038101166589], ['text analysis', 7.829080128288088], ['text categorization', 7.828008455667878], ['decision tree induction', 7.821588809863431], ['automatic image annotation', 7.819846336108936], ['multi-label classification', 7.816567315796455], ['statistical machine translation', 7.8141773665904655], ['text classification', 7.807495985018936], ['association analysis', 7.804665009617877], ['music retrieval', 7.804416496292528], ['selectivity estimation', 7.802374688266308], ['topic modeling', 7.797223708687896], ['test generation', 7.794357281057161], ['conceptual clustering', 7.794137097169592], ['predictive modeling', 7.789622168073497], ['spreading activation', 7.789270342732095], ['associative classification', 7.785249096552618]]
# ========================================
# Add entity query expansion with confidence score -0.280880907163
# Add entity text clustering with confidence score -0.172474983125
# Add entity mobile robotics with confidence score -0.242317943849
# Add entity document classification with confidence score -0.178711549929
# Add entity statistical pattern recognition with confidence score -0.231205169064
# [INFO] Finish SetExpan for one set
# Expanded set:
# 15042 supervised machine learning 0.0
# 16106 unsupervised learning 0.0
# 12815 reinforcement learning 0.0
# 11186 pattern mining 0.0
# 6257 graph mining 0.0
# 16714 web mining 0.0
# 15448 text mining 0.0
# 4144 document retrieval 0.0
# 12403 query processing 0.0
# 12886 relevance feedback 0.0
# 12388 query expansion -0.280880907163
# 15437 text clustering -0.172474983125
# 9538 mobile robotics -0.242317943849
# 4127 document classification -0.178711549929
# 14723 statistical pattern recognition -0.231205169064
# [[12388, -0.2808809071633156], [15437, -0.17247498312501786], [9538, -0.24231794384866334], [4127, -0.17871154992872551], [14723, -0.23120516906350633]]
# eid= 12388 ename= query expansion confidence_score= -0.280880907163
# eid= 15437 ename= text clustering confidence_score= -0.172474983125
# eid= 9538 ename= mobile robotics confidence_score= -0.242317943849
# eid= 4127 ename= document classification confidence_score= -0.178711549929
# eid= 14723 ename= statistical pattern recognition confidence_score= -0.231205169064
# Embedding_sim: 0.5204835018624495
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.7214454254220825
# Overall_sim: 0.5204835018624495
# 0.520484 0.000000 0.520484
# 0.5204835018624495
# Embedding_sim: 0.35825530387898064
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.5985443207307046
# Overall_sim: 0.35825530387898064
# 0.358255 0.000000 0.358255
# 0.35825530387898064
# Embedding_sim: 0.300219897852254
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.5479232590904076
# Overall_sim: 0.300219897852254
# 0.300220 0.000000 0.300220
# 0.300219897852254
# Embedding_sim: 0.22788276450505274
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.4773706783046616
# Overall_sim: 0.22788276450505274
# 0.227883 0.000000 0.227883
# 0.22788276450505274
# Embedding_sim: 0.3986095280443216
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.6313553104586368
# Overall_sim: 0.3986095280443216
# 0.398610 0.000000 0.398610
# 0.3986095280443216
# Embedding_sim: 0.6408696597408151
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.8005433528178315
# Overall_sim: 0.6408696597408151
# 0.640870 0.000000 0.640870
# 0.6408696597408151
# Embedding_sim: 0.5740056829309957
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.7576316274621828
# Overall_sim: 0.5740056829309957
# 0.574006 0.000000 0.574006
# 0.5740056829309957
# Embedding_sim: 0.4924262857973084
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.70173092122074
# Overall_sim: 0.4924262857973084
# 0.492426 0.000000 0.492426
# 0.4924262857973084
# Embedding_sim: 0.42183389809949723
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.6494874118098805
# Overall_sim: 0.42183389809949723
# 0.421834 0.000000 0.421834
# 0.42183389809949723
# Embedding_sim: 0.5931126130984694
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.7701380480786996
# Overall_sim: 0.5931126130984694
# 0.593113 0.000000 0.593113
# 0.5931126130984694
# Embedding_sim: 0.6563481064762898
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.8101531376698419
# Overall_sim: 0.6563481064762898
# 0.656348 0.000000 0.656348
# 0.6563481064762898
# Embedding_sim: 0.445681305397962
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.667593667883363
# Overall_sim: 0.445681305397962
# 0.445681 0.000000 0.445681
# 0.445681305397962
# Embedding_sim: 0.396803752244431
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.6299236082608993
# Overall_sim: 0.396803752244431
# 0.396804 0.000000 0.396804
# 0.396803752244431
# Embedding_sim: 0.2876234168077517
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.5363053391564844
# Overall_sim: 0.2876234168077517
# 0.287623 0.000000 0.287623
# 0.2876234168077517
# Embedding_sim: 0.5867611988494613
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.7660033934973535
# Overall_sim: 0.5867611988494613
# 0.586761 0.000000 0.586761
# 0.5867611988494613
# Embedding_sim: 0.5651839785518356
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.7517871896699462
# Overall_sim: 0.5651839785518356
# 0.565184 0.000000 0.565184
# 0.5651839785518356
# Embedding_sim: 0.4593752246807301
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.6777722513357493
# Overall_sim: 0.4593752246807301
# 0.459375 0.000000 0.459375
# 0.4593752246807301
# Embedding_sim: 0.3887573171785603
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.6235040634819955
# Overall_sim: 0.3887573171785603
# 0.388757 0.000000 0.388757
# 0.3887573171785603
# Embedding_sim: 0.2517164219499367
# Co-occurrence_sim: 3.2507287088542745
# Scaled_embedding_sim: 0.5017134859159526
# Overall_sim: 0.5189711836153474
# 0.251716 3.250729 0.518971
# 0.5189711836153474
# Embedding_sim: 0.5052931280637614
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.7108397344435392
# Overall_sim: 0.5052931280637614
# 0.505293 0.000000 0.505293
# 0.5052931280637614
# Embedding_sim: 0.6316405597976787
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.7947581769303659
# Overall_sim: 0.6316405597976787
# 0.631641 0.000000 0.631641
# 0.6316405597976787
# Embedding_sim: 0.4269596158521206
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.6534214687719716
# Overall_sim: 0.4269596158521206
# 0.426960 0.000000 0.426960
# 0.4269596158521206
# Embedding_sim: 0.5035915819371325
# Co-occurrence_sim: 3.2888311814866458
# Scaled_embedding_sim: 0.7096418687881462
# Overall_sim: 1.042912655779117
# 0.503592 3.288831 1.042913
# 1.042912655779117
# Embedding_sim: 0.25387039680539003
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.503855531680848
# Overall_sim: 0.25387039680539003
# 0.253870 0.000000 0.253870
# 0.25387039680539003
# Embedding_sim: 0.49463423191490374
# Co-occurrence_sim: 0.0
# Scaled_embedding_sim: 0.7033023758774769
# Overall_sim: 0.49463423191490374
# 0.494634 0.000000 0.494634
# 0.49463423191490374

# %%
# rootNode.printSubtree(0)

# rootNode.children[0].printSubtree(0)
print(rootNode.level)

targetNode = rootNode
MAX_LEVEL = 1
level = -1 

def getNodesByLevel(node, level):
    if node.level == level:
        return [node]
    
    res = []
    for child in node.children:
        res + getNodesByLevel(child, level)
        
    return res

getNodesByLevel(rootNode, -1)


'''
while level > MAX_LEVEL:
    level += 1
    seedEidsWithConfidence = [(child.eid, child.confidence_score) for child in targetNode.children]
    newOrderedChildrenEidsWithConfidence = runSetExpan(seedEidsWithConfidence)
    print(newOrderedChildrenEidsWithConfidence)
    for ele in newOrderedChildrenEidsWithConfidence:
        if targetNode.level == -1: #root
            newChildEid = ele[0]
            confidence_score = ele[1]
            newChild = TreeNode(parent=targetNode, level=targetNode.level+1, eid=newChildEid, ename=eid2ename[newChildEid],
                                  isUserProvided=False, confidence_score=confidence_score,
                                  max_children=level2max_children[targetNode.level+1])
            rootNode.addChildren([newChild])


        else:
            # calculate best parent to attach to 
            max_sim = 0
            best_parent = None
            for p in targetNode.parent.children: # find all parents for this child 
                sim = sim_par_new(p[0], c[0], reference_edges, 0.5, eid2embed, eidpair2PPMI, embed_dim=100,
                        DEBUG=False)

                print(eid2ename[p[0]], ":", eid2ename[newChildEid, sim])

                if sim >  max_sim:
                    max_sim = sim
                    best_parent = p

            if p is not None:
                newChild = TreeNode(parent=p, level=p.level+1, eid=newChildEid, ename=eid2ename[newChildEid],
                                  isUserProvided=False, confidence_score=confidence_score,
                                  max_children=level2max_children[p.level+1]) 
                p.addChildren([newChild])

'''
# Out:
# -1
#   File "<ipython-input-46-750b1644b2a4>", line 22
#     return
#           ^
# SyntaxError: 'return' outside function

# %%
for c in expandedChildren:
    for p in expandedParent:
        sim = sim_par_new(p[0], c[0], reference_edges, 0.5, eid2embed, eidpair2PPMI, embed_dim=100,
                    DEBUG=False)
        print(eid2ename[p[0]], ":", eid2ename[c[0]], sim)
# Out:
# artificial intelligence : query expansion 0.5204835018624495
# web mining : query expansion 0.35825530387898064
# pattern recognition : query expansion 0.300219897852254
# opinion mining : query expansion 0.22788276450505274
# computational linguistics : query expansion 0.3986095280443216
# artificial intelligence : text clustering 0.6408696597408151
# web mining : text clustering 0.5740056829309957
# pattern recognition : text clustering 0.4924262857973084
# opinion mining : text clustering 0.42183389809949723
# computational linguistics : text clustering 0.5931126130984694
# artificial intelligence : mobile robotics 0.6563481064762898
# web mining : mobile robotics 0.445681305397962
# pattern recognition : mobile robotics 0.396803752244431
# opinion mining : mobile robotics 0.2876234168077517
# computational linguistics : mobile robotics 0.5867611988494613
# artificial intelligence : document classification 0.5651839785518356
# web mining : document classification 0.4593752246807301
# pattern recognition : document classification 0.3887573171785603
# opinion mining : document classification 0.5189711836153474
# computational linguistics : document classification 0.5052931280637614
# artificial intelligence : statistical pattern recognition 0.6316405597976787
# web mining : statistical pattern recognition 0.4269596158521206
# pattern recognition : statistical pattern recognition 1.042912655779117
# opinion mining : statistical pattern recognition 0.25387039680539003
# computational linguistics : statistical pattern recognition 0.49463423191490374

# %%
print('loading eid pair document-level PPMI score')
eidpair2PPMI = util.loadEidDocPairPPMI(folder + 'eidDocPairPPMI.txt')
# Out:
# loading eid pair document-level PPMI score

# %%
import numpy as np
from scipy.spatial import distance
import math


def sim_par_new(p_eid, c_eid, reference_edges, embed_alpha, eid2embed, eidpair2PPMI, embed_dim=100, DEBUG=False):
  '''
  reference_edges: a list of (parent, child) eids
  embed_alpha: relative weight of embedding, set 1.0 to use only embedding, set 0.0 to use only document-co-occurrence
  '''

  ## embedding offest similarity
  target_offset = np.zeros([1, embed_dim])
  for edge in reference_edges:
    target_offset += (eid2embed[edge[0]] - eid2embed[edge[1]])
  target_offset /= (len(reference_edges))

  current_relation_offset = eid2embed[p_eid] - eid2embed[c_eid]
  embedding_sim = float(1.0 - distance.cdist(current_relation_offset, target_offset, 'cosine'))
  if embedding_sim < 0:
    embedding_sim = 0.0

  ## docPPMI similarity
  if frozenset([c_eid, p_eid]) in eidpair2PPMI:
    cooccur_sim = eidpair2PPMI[frozenset([c_eid, p_eid])]
  else:
    cooccur_sim = 0.0

  # overall_sim = ( embedding_sim ** embed_alpha ) * (cooccur_sim ** (1-embed_alpha))
  overall_sim = embedding_sim * math.sqrt(1 + cooccur_sim)
  if DEBUG:
    print("Embedding_sim:", embedding_sim)
    print("Co-occurrence_sim:", cooccur_sim)
    print("Scaled_embedding_sim:", (embedding_sim ** (1 - embed_alpha)))
    print("Overall_sim:", overall_sim)
    print("%.6f" % embedding_sim, "%.6f" % cooccur_sim, "%.6f" % overall_sim)
  return overall_sim




parent_eid = 8723
child_eid = 3362
# reference_edges_by_name = []
# reference_edges = [(3362, 16714)]
sim = sim_par_new(parent_eid, child_eid, reference_edges, 0.5, eid2embed, eidpair2PPMI, embed_dim=100,
                DEBUG=True)
print("sim", sim)
# Out:
# Embedding_sim: 0.0
# Co-occurrence_sim: 2.2697711816319153
# Scaled_embedding_sim: 0.0
# Overall_sim: 0.0
# 0.000000 2.269771 0.000000
# sim 0.0
