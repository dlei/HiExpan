# %%
# @dlei5

# import libs
import numpy as np
from scipy.spatial import distance
import math

import util
import set_expan
import time
import pickle

from tree_node import TreeNode
from collections import defaultdict

# %%
# set up global vars

level2max_children = {-1:10, 0:15, 1:5, 2:1e9, 3:1e9, 4:1e9, 5:1e9}
level2reference_edges = defaultdict(list)
negativeSeedEids = set()
load_pickle_flag = True
FLAGS_USE_TYPE = True



data = "dblpv2"
folder = '../../data/'+data+'/intermediate/'

"""
userInput = [
  ["ROOT", -1, ["machine learning", "data mining", "information retrieval"]],

  ["machine learning", 0, ["supervised machine learning", "unsupervised learning", "reinforcement learning"]],
  ["data mining", 0, ["pattern mining", "graph mining", "web mining", "text mining"]],
  ["information retrieval", 0, ["document retrieval", "query processing", "relevance feedback"]],
    
  ["supervised machine learning", 1, ["support vector machines"]]
]
"""

userInput = [
  ["ROOT", -1, ["machine learning", "data mining", "information retrieval"]],

  ["machine learning", 0, ["supervised machine learning", "unsupervised learning", "reinforcement learning"]],
  ["data mining", 0, ["pattern mining", "graph mining", "web mining", "text mining"]],
  ["information retrieval", 0, ["document retrieval", "query processing", "relevance feedback"]],

  ["supervised machine learning", 1, ["support vector machines", "decision trees", "random forests"]],
  ["unsupervised learning", 1, ["agglomerative clustering", "principle component analysis", "latent dirichlet allocation"]],
  ["reinforcement learning", 1, ["markov decision processes", "policy gradient"]]
  # ["supervised machine learning", 0, ["named entity recognition", "information extraction", "machine translation"]],
  # ["neural networks", 1, ["convolutional neural network", "recurrent neural networks"]],
]

# %%
# load pickle data 

print("=== Start loading all files ...... ===")
print("load_from_pickle")
pickle_file = '../../data/' + data + '/intermediate/all_data.pickle'
with open(pickle_file, "rb") as fin:
    [eid2ename, ename2eid, eid2patterns, pattern2eids, eidAndPattern2strength, eid2types, type2eids,
     eidAndType2strength, eid2embed, embed_matrix, eid2rank, rank2eid, embed_matrix_array, skipgramsByEidPairMap,
     eidPairsBySkipgramMap, weightByEidPairAndSkipgramMap] = pickle.load(fin)
print("=== Finish loading all files. HaHaHa ===")


# load PPMI
print('loading eid pair document-level PPMI score')
eidpair2PPMI = util.loadEidDocPairPPMI(folder + 'eidDocPairPPMI.txt')
# Out:
# === Start loading all files ...... ===
# load_from_pickle
# === Finish loading all files. HaHaHa ===
# loading eid pair document-level PPMI score

# %%
# define functions 
def sim_par_new(p_eid, c_eid, reference_edges, embed_alpha, eid2embed, eidpair2PPMI, embed_dim=100, DEBUG=False):
  '''
  reference_edges: a list of (parent, child) eids
  embed_alpha: relative weight of embedding, set 1.0 to use only embedding, set 0.0 to use only document-co-occurrence
  '''

  ## embedding offest similarity
  target_offset = np.zeros([1, embed_dim])
  for edge in reference_edges:
    target_offset += (eid2embed[edge[0]] - eid2embed[edge[1]])
  target_offset /= (len(reference_edges))

  current_relation_offset = eid2embed[p_eid] - eid2embed[c_eid]
  embedding_sim = float(1.0 - distance.cdist(current_relation_offset, target_offset, 'cosine'))
  if embedding_sim < 0:
    embedding_sim = 0.0

  ## docPPMI similarity
  if frozenset([c_eid, p_eid]) in eidpair2PPMI:
    cooccur_sim = eidpair2PPMI[frozenset([c_eid, p_eid])]
  else:
    cooccur_sim = 0.0

  # overall_sim = ( embedding_sim ** embed_alpha ) * (cooccur_sim ** (1-embed_alpha))
  overall_sim = embedding_sim * math.sqrt(1 + cooccur_sim)
  if DEBUG:
    print("Embedding_sim:", embedding_sim)
    print("Co-occurrence_sim:", cooccur_sim)
    print("Scaled_embedding_sim:", (embedding_sim ** (1 - embed_alpha)))
    print("Overall_sim:", overall_sim)
    print("%.6f" % embedding_sim, "%.6f" % cooccur_sim, "%.6f" % overall_sim)
  return overall_sim


def runSetExpan(seedEidsWithConfidence, numToExpan):
    expandedEidsWithConfidence = set_expan.setExpan(
        seedEidsWithConfidence=seedEidsWithConfidence,
        negativeSeedEids=negativeSeedEids,
        eid2patterns=eid2patterns,
        pattern2eids=pattern2eids,
        eidAndPattern2strength=eidAndPattern2strength,
        eid2types=eid2types,
        type2eids=type2eids,
        eidAndType2strength=eidAndType2strength,
        eid2ename=eid2ename,
        eid2embed=eid2embed,
        source_weights={"sg":1.0, "tp":5.0, "eb":5.0},
        max_expand_eids=numToExpan,
        use_embed=True,
        use_type=True,
        FLAGS_VERBOSE=False,
        FLAGS_DEBUG=False
    )
    print(expandedEidsWithConfidence)
    for ele in expandedEidsWithConfidence:
      print("eid=", ele[0], "ename=", eid2ename[ele[0]], "confidence_score=", ele[1])

    
    return expandedEidsWithConfidence


def obtainReferenceEdges(targetNode):
  reference_edges = []
  ## Add 1) edges in user guidance and 2) first FLAGS_INITIAL_EDGE edge under each sibling nodes as
  # reference edges
  for sibling in targetNode.parent.children:
    print(sibling)
    cnt = 0
    for cousin in sibling.children:
      print(cousin)
      if cousin.isUserProvided and sibling.isUserProvided:
        reference_edges.append((sibling.eid, cousin.eid))
      else:
        reference_edges.append((sibling.eid, cousin.eid))
        cnt += 1
        if cnt >= FLAGS_INITIAL_EDGE:
          break
  return reference_edges


def init():
    # generate reference edges
    rootNode = None
    ename2treeNode = {}
    for i, node in enumerate(userInput):
      if i == 0: ## ROOT
        rootNode = TreeNode(parent=None, level=-1, eid=-1, ename="ROOT", isUserProvided=True, confidence_score=0.0,
                            max_children=level2max_children[-1])
        ename2treeNode["ROOT"] = rootNode
        for children in node[2]:
          newNode = TreeNode(parent=rootNode, level=0, eid=ename2eid[children], ename=children, isUserProvided=True,
                             confidence_score=0.0, max_children=level2max_children[0])
          ename2treeNode[children] = newNode
          rootNode.addChildren([newNode])
      else:
        ename = node[0]
        eid = ename2eid[ename]  # assume user supervision is an entity mention in entity2id.txt
        level = node[1]
        childrens = node[2]
        if ename in ename2treeNode: # existing node
          parent_treeNode = ename2treeNode[ename]
          for children in childrens:
            newNode = TreeNode(parent=parent_treeNode, level=parent_treeNode.level+1, eid=ename2eid[children],
                               ename=children, isUserProvided=True, confidence_score=0.0,
                               max_children=level2max_children[parent_treeNode.level+1])
            ename2treeNode[children] = newNode
            parent_treeNode.addChildren([newNode])
            level2reference_edges[parent_treeNode.level].append((parent_treeNode.eid, newNode.eid))
        else: # not existing node
          print("[ERROR] disconnected tree node: %s" % node)
        
    return rootNode


def getNodesByLevel(node, level):
    if node.level == level:
        return [node]
    
    res = []
    for child in node.children:
        res = res + getNodesByLevel(child, level)
        
    return res

# %%
rootNode = init()
rootNode.printSubtree(0)
reference_edges = obtainReferenceEdges(rootNode.children[0])


level = -1 # start from root
MAX_LEVEL = 2
targetNode = rootNode
while level < MAX_LEVEL:
    
    level += 1
    print(level)
    
    seedEidsWithConfidence = [(child.eid, child.confidence_score) for child in getNodesByLevel(rootNode, level)]
    newOrderedChildrenEidsWithConfidence = runSetExpan(seedEidsWithConfidence, 3 ** level)
    
    print(newOrderedChildrenEidsWithConfidence)
    for ele in newOrderedChildrenEidsWithConfidence:
        newChildEid = ele[0]
        confidence_score = ele[1]
            
        if level == 0: # first level, just append them to root

            newChild = TreeNode(parent=rootNode, level=level, eid=newChildEid, ename=eid2ename[newChildEid],
                                  isUserProvided=False, confidence_score=confidence_score,
                                  max_children=level2max_children[targetNode.level+1])
            rootNode.addChildren([newChild])


        else:
            # calculate best parent to attach to 
            max_sim = 0
            best_parent = None
            for p in getNodesByLevel(rootNode, level-1): # find all parents for this child 
#                 obtainReferenceEdges(rootNode.children[0])
                sim = sim_par_new(p.eid, ele[0], reference_edges, 0.5, eid2embed, eidpair2PPMI, embed_dim=100, DEBUG=False)
#                 sim = sim_par_new(p.eid, ele[0], obtainReferenceEdges(), 0.5, eid2embed, eidpair2PPMI, embed_dim=100,
#                                     DEBUG=False)

                print(p.ename, ":", eid2ename[newChildEid], sim)

                if sim >  max_sim:
                    max_sim = sim
                    best_parent = p

            print("=== attaching", eid2ename[ele[0]], " to ", best_parent.ename)
            if best_parent is not None:
                newChild = TreeNode(parent=best_parent, level=level, eid=newChildEid, ename=eid2ename[newChildEid],
                                  isUserProvided=False, confidence_score=confidence_score,
                                  max_children=level2max_children[p.level+1]) 
                best_parent.addChildren([newChild])
                
                
rootNode.printSubtree(0)
# Out:
# ROOT  (eid=-1, log_prob=0.000000)
# 	machine learning  (eid=8723, log_prob=0.000000)
# 		supervised machine learning  (eid=15042, log_prob=0.000000)
# 			support vector machines  (eid=15066, log_prob=0.000000)
# 		unsupervised learning  (eid=16106, log_prob=0.000000)
# 		reinforcement learning  (eid=12815, log_prob=0.000000)
# 	data mining  (eid=3362, log_prob=0.000000)
# 		pattern mining  (eid=11186, log_prob=0.000000)
# 		graph mining  (eid=6257, log_prob=0.000000)
# 		web mining  (eid=16714, log_prob=0.000000)
# 		text mining  (eid=15448, log_prob=0.000000)
# 	information retrieval  (eid=7348, log_prob=0.000000)
# 		document retrieval  (eid=4144, log_prob=0.000000)
# 		query processing  (eid=12403, log_prob=0.000000)
# 		relevance feedback  (eid=12886, log_prob=0.000000)
# machine learning (eid=8723,log_prob=0.000000,parent=ROOT)
# supervised machine learning (eid=15042,log_prob=0.000000,parent=machine learning)
# unsupervised learning (eid=16106,log_prob=0.000000,parent=machine learning)
# reinforcement learning (eid=12815,log_prob=0.000000,parent=machine learning)
# data mining (eid=3362,log_prob=0.000000,parent=ROOT)
# pattern mining (eid=11186,log_prob=0.000000,parent=data mining)
# graph mining (eid=6257,log_prob=0.000000,parent=data mining)
# web mining (eid=16714,log_prob=0.000000,parent=data mining)
# text mining (eid=15448,log_prob=0.000000,parent=data mining)
# information retrieval (eid=7348,log_prob=0.000000,parent=ROOT)
# document retrieval (eid=4144,log_prob=0.000000,parent=information retrieval)
# query processing (eid=12403,log_prob=0.000000,parent=information retrieval)
# relevance feedback (eid=12886,log_prob=0.000000,parent=information retrieval)
# 0
# [[697, 0.0], [11187, 0.0], [2603, -0.083427839456251193], [6928, -0.072249071047900265], [1268, -0.20903437745503423]]
# eid= 697 ename= artificial intelligence confidence_score= 0.0
# eid= 11187 ename= pattern recognition confidence_score= 0.0
# eid= 2603 ename= computational linguistics confidence_score= -0.0834278394563
# eid= 6928 ename= human-computer interaction confidence_score= -0.0722490710479
# eid= 1268 ename= biomedical research confidence_score= -0.209034377455
# [[697, 0.0], [11187, 0.0], [2603, -0.083427839456251193], [6928, -0.072249071047900265], [1268, -0.20903437745503423]]
# 1
# [[12388, -0.2808809071633156], [15437, -0.17247498312501786], [9538, -0.24231829562721935], [13164, -0.29014770545260354], [4127, -0.2234540806897744], [16740, -0.23631813369672452], [4125, -0.25995546945196785], [15257, -0.3710747345398418], [5781, -0.36556284137304945], [16400, -0.29299200339193121], [13277, -0.30480331439679098], [9290, -0.70541314565802093], [1480, -0.53813835475592309], [14394, -0.32844685840063448], [15093, -0.41241510015783528]]
# eid= 12388 ename= query expansion confidence_score= -0.280880907163
# eid= 15437 ename= text clustering confidence_score= -0.172474983125
# eid= 9538 ename= mobile robotics confidence_score= -0.242318295627
# eid= 13164 ename= robot control confidence_score= -0.290147705453
# eid= 4127 ename= document classification confidence_score= -0.22345408069
# eid= 16740 ename= web usage mining confidence_score= -0.236318133697
# eid= 4125 ename= document analysis confidence_score= -0.259955469452
# eid= 15257 ename= target tracking confidence_score= -0.37107473454
# eid= 5781 ename= gait recognition confidence_score= -0.365562841373
# eid= 16400 ename= video retrieval confidence_score= -0.292992003392
# eid= 13277 ename= rule discovery confidence_score= -0.304803314397
# eid= 9290 ename= microarray experiments confidence_score= -0.705413145658
# eid= 1480 ename= brain-computer interface confidence_score= -0.538138354756
# eid= 14394 ename= spam detection confidence_score= -0.328446858401
# eid= 15093 ename= surveillance systems confidence_score= -0.412415100158
# [[12388, -0.2808809071633156], [15437, -0.17247498312501786], [9538, -0.24231829562721935], [13164, -0.29014770545260354], [4127, -0.2234540806897744], [16740, -0.23631813369672452], [4125, -0.25995546945196785], [15257, -0.3710747345398418], [5781, -0.36556284137304945], [16400, -0.29299200339193121], [13277, -0.30480331439679098], [9290, -0.70541314565802093], [1480, -0.53813835475592309], [14394, -0.32844685840063448], [15093, -0.41241510015783528]]
# machine learning : query expansion 0.5829467053331923
# data mining : query expansion 0.5449017165486164
# information retrieval : query expansion 1.4296869251326723
# artificial intelligence : query expansion 0.5204835018624495
# pattern recognition : query expansion 0.300219897852254
# computational linguistics : query expansion 0.3986095280443216
# human-computer interaction : query expansion 0.27690663514240244
# biomedical research : query expansion 0.1787402798306884
# === attaching query expansion  to  information retrieval
# machine learning : text clustering 0.7536446830986323
# data mining : text clustering 0.7727738496563265
# information retrieval : text clustering 1.0560251091025334
# artificial intelligence : text clustering 0.6408696597408151
# pattern recognition : text clustering 0.4924262857973084
# computational linguistics : text clustering 0.5931126130984694
# human-computer interaction : text clustering 0.3918100329164701
# biomedical research : text clustering 0.31345964249535596
# === attaching text clustering  to  information retrieval
# machine learning : mobile robotics 0.6195742832951872
# data mining : mobile robotics 0.6923227575804499
# information retrieval : mobile robotics 0.48520858587680493
# artificial intelligence : mobile robotics 0.6563481064762898
# pattern recognition : mobile robotics 0.396803752244431
# computational linguistics : mobile robotics 0.5867611988494613
# human-computer interaction : mobile robotics 0.38035141188364474
# biomedical research : mobile robotics 0.24713234055238842
# === attaching mobile robotics  to  data mining
# machine learning : robot control 0.8556985917724005
# data mining : robot control 0.7330765257933866
# information retrieval : robot control 0.5536114118138548
# artificial intelligence : robot control 1.1360325038485584
# pattern recognition : robot control 0.4815314369593888
# computational linguistics : robot control 0.6234102711050247
# human-computer interaction : robot control 0.4697388739757744
# biomedical research : robot control 0.3798186727334003
# === attaching robot control  to  artificial intelligence
# machine learning : document classification 1.3950197132192121
# data mining : document classification 1.0205619935041002
# information retrieval : document classification 0.8476367809329016
# artificial intelligence : document classification 0.5651839785518356
# pattern recognition : document classification 0.3887573171785603
# computational linguistics : document classification 0.5052931280637614
# human-computer interaction : document classification 0.2983401974003608
# biomedical research : document classification 0.17912858395253117
# === attaching document classification  to  machine learning
# machine learning : web usage mining 0.7984533279574862
# data mining : web usage mining 1.5512498453124888
# information retrieval : web usage mining 0.467018825614131
# artificial intelligence : web usage mining 0.8958546281011573
# pattern recognition : web usage mining 0.29653364866518905
# computational linguistics : web usage mining 0.9467241640823655
# human-computer interaction : web usage mining 0.25181479932259077
# biomedical research : web usage mining 0.13733873097087057
# === attaching web usage mining  to  data mining
# machine learning : document analysis 1.0314125910762733
# data mining : document analysis 0.7113133771321714
# information retrieval : document analysis 1.0896973250247683
# artificial intelligence : document analysis 1.0121809004809312
# pattern recognition : document analysis 0.89081707993627
# computational linguistics : document analysis 0.6478322784460493
# human-computer interaction : document analysis 0.42092500878353856
# biomedical research : document analysis 0.29596591034327147
# === attaching document analysis  to  information retrieval
# machine learning : target tracking 0.7050307817725898
# data mining : target tracking 0.7660246945218726
# information retrieval : target tracking 0.6003500010318134
# artificial intelligence : target tracking 0.8513078552126018
# pattern recognition : target tracking 0.6057246102667807
# computational linguistics : target tracking 0.6783403349636457
# human-computer interaction : target tracking 1.3325090125152792
# biomedical research : target tracking 0.4909508522950864
# === attaching target tracking  to  human-computer interaction
# machine learning : gait recognition 0.747303574018715
# data mining : gait recognition 0.7075862034883298
# information retrieval : gait recognition 0.6303673589716936
# artificial intelligence : gait recognition 0.6897167743490388
# pattern recognition : gait recognition 1.033259431722273
# computational linguistics : gait recognition 0.6280285351441488
# human-computer interaction : gait recognition 0.9886856750102888
# biomedical research : gait recognition 0.41688935418714346
# === attaching gait recognition  to  pattern recognition
# machine learning : video retrieval 0.9330638478592507
# data mining : video retrieval 0.7159683662507802
# information retrieval : video retrieval 1.0786582097854283
# artificial intelligence : video retrieval 0.6260917986731519
# pattern recognition : video retrieval 0.44678124803639807
# computational linguistics : video retrieval 0.6185955391564266
# human-computer interaction : video retrieval 0.7990930367457623
# biomedical research : video retrieval 0.3388280117296588
# === attaching video retrieval  to  information retrieval
# machine learning : rule discovery 1.1002756300256806
# data mining : rule discovery 1.509163790923488
# information retrieval : rule discovery 0.6129142358603589
# artificial intelligence : rule discovery 0.6987895703716385
# pattern recognition : rule discovery 0.5272791603683791
# computational linguistics : rule discovery 0.6614674303052779
# human-computer interaction : rule discovery 0.4596822864555532
# biomedical research : rule discovery 0.38105769637836495
# === attaching rule discovery  to  data mining
# machine learning : microarray experiments 0.5183426356045143
# data mining : microarray experiments 0.5948726321077445
# information retrieval : microarray experiments 0.3870268600745098
# artificial intelligence : microarray experiments 0.4886837687965251
# pattern recognition : microarray experiments 0.339678096801036
# computational linguistics : microarray experiments 0.3855448923425975
# human-computer interaction : microarray experiments 0.26479178546380955
# biomedical research : microarray experiments 0.27241797801105794
# === attaching microarray experiments  to  data mining
# machine learning : brain-computer interface 0.731937971035204
# data mining : brain-computer interface 0.5416514918129883
# information retrieval : brain-computer interface 0.4162767826883288
# artificial intelligence : brain-computer interface 0.5736508231867887
# pattern recognition : brain-computer interface 0.5524009746279557
# computational linguistics : brain-computer interface 0.43923013344862594
# human-computer interaction : brain-computer interface 0.5371083042186753
# biomedical research : brain-computer interface 0.16216307316668233
# === attaching brain-computer interface  to  machine learning
# machine learning : spam detection 1.1943679008264187
# data mining : spam detection 0.8018266898889852
# information retrieval : spam detection 0.6359231013109371
# artificial intelligence : spam detection 0.7055470562483036
# pattern recognition : spam detection 0.5460147214407833
# computational linguistics : spam detection 0.6833220807287191
# human-computer interaction : spam detection 0.49611395105197187
# biomedical research : spam detection 0.4658217683380794
# === attaching spam detection  to  machine learning
# machine learning : surveillance systems 0.6315311805522591
# data mining : surveillance systems 0.6774774887268908
# information retrieval : surveillance systems 0.5565923729933174
# artificial intelligence : surveillance systems 1.0190138474655754
# pattern recognition : surveillance systems 0.5578752197036777
# computational linguistics : surveillance systems 0.6110694377800558
# human-computer interaction : surveillance systems 0.9136637470321535
# biomedical research : surveillance systems 0.41187560274895363
# === attaching surveillance systems  to  artificial intelligence
# 2
# [[8369, 0.0], [10022, 0.0], [10231, 0.0], [7816, -0.066837228701791096], [7819, -0.088544323378328599], [12494, 0.0], [8562, -0.062026353782166366], [8335, 0.0], [1064, -0.01475871170787668], [3490, -0.068937091643396425], [10023, -0.12595076182689699], [7814, -0.10041115016353214], [2171, -0.15038368124242413], [702, -0.26432780113263504], [13108, -0.1812655451779529], [9790, -0.16460656466978082], [9007, -0.15474051735125166], [8676, -0.17957688838816005], [3493, -0.24195959687456589], [12781, -0.21852516087747248], [10114, -0.22436840076812634], [12798, -0.24547904343039118], [11942, -0.21655860038836772], [7850, -0.22863959118177107], [10230, -0.24763978041197454], [8192, -0.22938079654935489], [1074, -0.40802661859348277], [15068, -0.28221397436417128], [1766, -0.29621842871454074], [1063, -0.35231387887423737], [2164, -0.30560512283502272], [16304, -0.30981703538719874], [12892, -0.28894929687073306], [2175, -0.28032224001020917], [4618, -0.29765639960347728], [929, -0.27824470513239058], [13627, -0.40099097613337709], [10237, -0.34081497191503823], [8887, -0.45244212454298699], [2739, -0.3278733057642963], [12304, -0.35219827140872417], [8194, -0.32888659460622743], [14723, -0.45730752396162067], [12703, -0.33956253997717317], [1050, -0.32384180642250615]]
# eid= 8369 ename= linear support vector machines confidence_score= 0.0
# eid= 10022 ename= naive bayes confidence_score= 0.0
# eid= 10231 ename= neural networks confidence_score= 0.0
# eid= 7816 ename= k-nearest neighbour confidence_score= -0.0668372287018
# eid= 7819 ename= nearest neighbor confidence_score= -0.0885443233783
# eid= 12494 ename= random forests confidence_score= 0.0
# eid= 8562 ename= logistic regression confidence_score= -0.0620263537822
# eid= 8335 ename= linear discriminant analysis confidence_score= 0.0
# eid= 1064 ename= bayesian classifier confidence_score= -0.0147587117079
# eid= 3490 ename= decision trees confidence_score= -0.0689370916434
# eid= 10023 ename= naive bayes classifier confidence_score= -0.125950761827
# eid= 7814 ename= k nearest neighbors confidence_score= -0.100411150164
# eid= 2171 ename= classification trees confidence_score= -0.150383681242
# eid= 702 ename= artificial neural networks confidence_score= -0.264327801133
# eid= 13108 ename= ridge regression confidence_score= -0.181265545178
# eid= 9790 ename= multilayer perceptron confidence_score= -0.16460656467
# eid= 9007 ename= maximum entropy confidence_score= -0.154740517351
# eid= 8676 ename= ls-svm confidence_score= -0.179576888388
# eid= 3493 ename= decision tree induction confidence_score= -0.241959596875
# eid= 12781 ename= regression trees confidence_score= -0.218525160877
# eid= 10114 ename= nearest neighbour confidence_score= -0.224368400768
# eid= 12798 ename= regularized least squares confidence_score= -0.24547904343
# eid= 11942 ename= probabilistic neural network confidence_score= -0.216558600388
# eid= 7850 ename= kernel pca confidence_score= -0.228639591182
# eid= 10230 ename= neural nets confidence_score= -0.247639780412
# eid= 8192 ename= learning vector quantization confidence_score= -0.229380796549
# eid= 1074 ename= bayesian networks confidence_score= -0.408026618593
# eid= 15068 ename= support vector regression confidence_score= -0.282213974364
# eid= 1766 ename= cascade correlation confidence_score= -0.296218428715
# eid= 1063 ename= bayesian classification confidence_score= -0.352313878874
# eid= 2164 ename= classification and regression trees confidence_score= -0.305605122835
# eid= 16304 ename= vector quantization confidence_score= -0.309817035387
# eid= 12892 ename= relevance vector machine confidence_score= -0.288949296871
# eid= 2175 ename= classifier ensemble confidence_score= -0.28032224001
# eid= 4618 ename= ensemble classifier confidence_score= -0.297656399603
# eid= 929 ename= back-propagation neural network confidence_score= -0.278244705132
# eid= 13627 ename= self-organizing map confidence_score= -0.400990976133
# eid= 10237 ename= neural network ensemble confidence_score= -0.340814971915
# eid= 8887 ename= markov model confidence_score= -0.452442124543
# eid= 2739 ename= conjugate gradient confidence_score= -0.327873305764
# eid= 12304 ename= quadratic discriminant analysis confidence_score= -0.352198271409
# eid= 8194 ename= least squares support vector machine confidence_score= -0.328886594606
# eid= 14723 ename= statistical pattern recognition confidence_score= -0.457307523962
# eid= 12703 ename= recursive feature elimination confidence_score= -0.339562539977
# eid= 1050 ename= bayes classifier confidence_score= -0.323841806423
# [[8369, 0.0], [10022, 0.0], [10231, 0.0], [7816, -0.066837228701791096], [7819, -0.088544323378328599], [12494, 0.0], [8562, -0.062026353782166366], [8335, 0.0], [1064, -0.01475871170787668], [3490, -0.068937091643396425], [10023, -0.12595076182689699], [7814, -0.10041115016353214], [2171, -0.15038368124242413], [702, -0.26432780113263504], [13108, -0.1812655451779529], [9790, -0.16460656466978082], [9007, -0.15474051735125166], [8676, -0.17957688838816005], [3493, -0.24195959687456589], [12781, -0.21852516087747248], [10114, -0.22436840076812634], [12798, -0.24547904343039118], [11942, -0.21655860038836772], [7850, -0.22863959118177107], [10230, -0.24763978041197454], [8192, -0.22938079654935489], [1074, -0.40802661859348277], [15068, -0.28221397436417128], [1766, -0.29621842871454074], [1063, -0.35231387887423737], [2164, -0.30560512283502272], [16304, -0.30981703538719874], [12892, -0.28894929687073306], [2175, -0.28032224001020917], [4618, -0.29765639960347728], [929, -0.27824470513239058], [13627, -0.40099097613337709], [10237, -0.34081497191503823], [8887, -0.45244212454298699], [2739, -0.3278733057642963], [12304, -0.35219827140872417], [8194, -0.32888659460622743], [14723, -0.45730752396162067], [12703, -0.33956253997717317], [1050, -0.32384180642250615]]
# supervised machine learning : linear support vector machines 0.17743572271613062
# unsupervised learning : linear support vector machines 0.21149634580900156
# reinforcement learning : linear support vector machines 0.24932213834309536
# document classification : linear support vector machines 0.7963856664513238
# brain-computer interface : linear support vector machines 0.32829936115496317
# spam detection : linear support vector machines 0.12313326682528425
# pattern mining : linear support vector machines 0.14300217915657398
# graph mining : linear support vector machines 0.224682948700353
# web mining : linear support vector machines 0.5456661553028364
# text mining : linear support vector machines 0.48994034788883833
# mobile robotics : linear support vector machines 0.2920424179942862
# web usage mining : linear support vector machines 0.3773944946884441
# rule discovery : linear support vector machines 0.18359857573941296
# microarray experiments : linear support vector machines 0.15392202907363584
# document retrieval : linear support vector machines 0.25669623966632493
# query processing : linear support vector machines 0.026794643325887435
# relevance feedback : linear support vector machines 0.07296959865775632
# query expansion : linear support vector machines 0.2150594217808397
# text clustering : linear support vector machines 0.2769020545141474
# document analysis : linear support vector machines 0.3234709497239674
# video retrieval : linear support vector machines 0.2228304343535109
# robot control : linear support vector machines 0.1758486348766266
# surveillance systems : linear support vector machines 0.19267656095309094
# gait recognition : linear support vector machines 0.038870416983650236
# target tracking : linear support vector machines 0.05385500500121765
# === attaching linear support vector machines  to  document classification
# supervised machine learning : naive bayes 0.020835185623253528
# unsupervised learning : naive bayes 0.063760486235096
# reinforcement learning : naive bayes 0.13410642338027545
# document classification : naive bayes 0.3181031307604765
# brain-computer interface : naive bayes 0.19499594181400054
# spam detection : naive bayes 0.002423345598622166
# pattern mining : naive bayes 0.02734987886451612
# graph mining : naive bayes 0.08387591971022901
# web mining : naive bayes 0.5455254985379613
# text mining : naive bayes 0.4719168653626792
# mobile robotics : naive bayes 0.13089947740973373
# web usage mining : naive bayes 0.18886509365477044
# rule discovery : naive bayes 0.03472318325740953
# microarray experiments : naive bayes 0.056391223884050934
# document retrieval : naive bayes 0.1551380759649152
# query processing : naive bayes 0.0
# relevance feedback : naive bayes 0.0
# query expansion : naive bayes 0.10990722597607216
# text clustering : naive bayes 0.1788723909520303
# document analysis : naive bayes 0.20753234737142257
# video retrieval : naive bayes 0.07751921123083572
# robot control : naive bayes 0.04377949729140074
# surveillance systems : naive bayes 0.06731291612415757
# gait recognition : naive bayes 0.0
# target tracking : naive bayes 0.0
# === attaching naive bayes  to  web mining
# supervised machine learning : neural networks 0.0
# unsupervised learning : neural networks 0.0
# reinforcement learning : neural networks 0.09399369477406969
# document classification : neural networks 0.06526617089528564
# brain-computer interface : neural networks 0.07526923336650115
# spam detection : neural networks 0.0
# pattern mining : neural networks 0.0
# graph mining : neural networks 0.0
# web mining : neural networks 0.2705216785897775
# text mining : neural networks 0.28739287874610747
# mobile robotics : neural networks 0.06294191962125506
# web usage mining : neural networks 0.11349006558844255
# rule discovery : neural networks 0.0
# microarray experiments : neural networks 0.0
# document retrieval : neural networks 0.03371848319764836
# query processing : neural networks 0.0
# relevance feedback : neural networks 0.0
# query expansion : neural networks 0.014429935038875574
# text clustering : neural networks 0.0
# document analysis : neural networks 0.04686530901815167
# video retrieval : neural networks 0.0
# robot control : neural networks 0.0
# surveillance systems : neural networks 0.0
# gait recognition : neural networks 0.0
# target tracking : neural networks 0.0
# === attaching neural networks  to  text mining
# supervised machine learning : k-nearest neighbour 0.19125021197061065
# unsupervised learning : k-nearest neighbour 0.21754202738089856
# reinforcement learning : k-nearest neighbour 0.2636846446908453
# document classification : k-nearest neighbour 0.3708367865707598
# brain-computer interface : k-nearest neighbour 0.3659906938012847
# spam detection : k-nearest neighbour 0.14279193077471342
# pattern mining : k-nearest neighbour 0.15068802568592177
# graph mining : k-nearest neighbour 0.22700284709846852
# web mining : k-nearest neighbour 1.078239328748897
# text mining : k-nearest neighbour 0.4747894977602367
# mobile robotics : k-nearest neighbour 0.3083132743396573
# web usage mining : k-nearest neighbour 0.38428411436918175
# rule discovery : k-nearest neighbour 0.20480690014862846
# microarray experiments : k-nearest neighbour 0.15519461982883542
# document retrieval : k-nearest neighbour 0.2666414405385734
# query processing : k-nearest neighbour 0.03516630871011761
# relevance feedback : k-nearest neighbour 0.08592186874642782
# query expansion : k-nearest neighbour 0.2247821432479169
# text clustering : k-nearest neighbour 0.284637328497672
# document analysis : k-nearest neighbour 0.3474350097565204
# video retrieval : k-nearest neighbour 0.23753430844234735
# robot control : k-nearest neighbour 0.20195949259154766
# surveillance systems : k-nearest neighbour 0.21235161866558716
# gait recognition : k-nearest neighbour 0.05465452502835633
# target tracking : k-nearest neighbour 0.07159383668102248
# === attaching k-nearest neighbour  to  web mining
# supervised machine learning : nearest neighbor 0.2477604822603366
# unsupervised learning : nearest neighbor 0.26812141136264483
# reinforcement learning : nearest neighbor 0.23512405840480322
# document classification : nearest neighbor 0.4907741833803243
# brain-computer interface : nearest neighbor 0.4072466347661839
# spam detection : nearest neighbor 0.13797762465189733
# pattern mining : nearest neighbor 0.24988182187252675
# graph mining : nearest neighbor 0.27186143805326357
# web mining : nearest neighbor 0.6352719734281042
# text mining : nearest neighbor 0.4292957865048852
# mobile robotics : nearest neighbor 0.2631649216229496
# web usage mining : nearest neighbor 0.3319755170929146
# rule discovery : nearest neighbor 0.17404909515116274
# microarray experiments : nearest neighbor 0.1843941499059669
# document retrieval : nearest neighbor 0.32339985513512093
# query processing : nearest neighbor 0.11849265382921904
# relevance feedback : nearest neighbor 0.16163368855340987
# query expansion : nearest neighbor 0.2301103064868515
# text clustering : nearest neighbor 0.2482175168429136
# document analysis : nearest neighbor 0.2675914711833658
# video retrieval : nearest neighbor 0.26450545485534127
# robot control : nearest neighbor 0.16550886583219593
# surveillance systems : nearest neighbor 0.18272386865797752
# gait recognition : nearest neighbor 0.10674694923124081
# target tracking : nearest neighbor 0.0846071528559027
# === attaching nearest neighbor  to  web mining
# supervised machine learning : random forests 0.07795114784399074
# unsupervised learning : random forests 0.14480139671382442
# reinforcement learning : random forests 0.1656086124912296
# document classification : random forests 0.22574133329645463
# brain-computer interface : random forests 0.19525812654206565
# spam detection : random forests 0.05252448594278913
# pattern mining : random forests 0.051408186976560244
# graph mining : random forests 0.11381237044720316
# web mining : random forests 0.3979908161420387
# text mining : random forests 0.3986611541824295
# mobile robotics : random forests 0.1676784717551224
# web usage mining : random forests 0.2375158960030288
# rule discovery : random forests 0.06441600113921164
# microarray experiments : random forests 0.11174532286752262
# document retrieval : random forests 0.1728536128454855
# query processing : random forests 0.0
# relevance feedback : random forests 0.01207623964811555
# query expansion : random forests 0.1440683270983737
# text clustering : random forests 0.13807479561490354
# document analysis : random forests 0.17183480966211295
# video retrieval : random forests 0.11290540772305047
# robot control : random forests 0.0716315150840986
# surveillance systems : random forests 0.09764685739851664
# gait recognition : random forests 0.0
# target tracking : random forests 0.0
# === attaching random forests  to  text mining
# supervised machine learning : logistic regression 0.0
# unsupervised learning : logistic regression 0.07953527601246263
# reinforcement learning : logistic regression 0.1359607258187776
# document classification : logistic regression 0.32830814911179274
# brain-computer interface : logistic regression 0.2620108655124386
# spam detection : logistic regression 0.0
# pattern mining : logistic regression 0.01855234218126578
# graph mining : logistic regression 0.07835081110509878
# web mining : logistic regression 0.4914904734554524
# text mining : logistic regression 0.3321151341302106
# mobile robotics : logistic regression 0.13888499790353015
# web usage mining : logistic regression 0.19592572240741268
# rule discovery : logistic regression 0.026215799063482148
# microarray experiments : logistic regression 0.07196214161229214
# document retrieval : logistic regression 0.12693505324552135
# query processing : logistic regression 0.0
# relevance feedback : logistic regression 0.0
# query expansion : logistic regression 0.10090060326400885
# text clustering : logistic regression 0.09486432249767984
# document analysis : logistic regression 0.137190393435621
# video retrieval : logistic regression 0.07414923335493417
# robot control : logistic regression 0.03727026498506325
# surveillance systems : logistic regression 0.06403763268864082
# gait recognition : logistic regression 0.0
# target tracking : logistic regression 0.0
# === attaching logistic regression  to  web mining
# supervised machine learning : linear discriminant analysis 0.027750797117650716
# unsupervised learning : linear discriminant analysis 0.13943266847293384
# reinforcement learning : linear discriminant analysis 0.13965342937604552
# document classification : linear discriminant analysis 0.180537972499909
# brain-computer interface : linear discriminant analysis 0.32029939574608385
# spam detection : linear discriminant analysis 0.01575947570565006
# pattern mining : linear discriminant analysis 0.044305735995656126
# graph mining : linear discriminant analysis 0.10243718105965094
# web mining : linear discriminant analysis 0.35674725996986356
# text mining : linear discriminant analysis 0.3449157715377116
# mobile robotics : linear discriminant analysis 0.1509466218952915
# web usage mining : linear discriminant analysis 0.20104803490280854
# rule discovery : linear discriminant analysis 0.05082820848931091
# microarray experiments : linear discriminant analysis 0.08691022649935311
# document retrieval : linear discriminant analysis 0.13683321302413687
# query processing : linear discriminant analysis 0.0
# relevance feedback : linear discriminant analysis 0.003701371866746017
# query expansion : linear discriminant analysis 0.11479333714367257
# text clustering : linear discriminant analysis 0.1184129629692966
# document analysis : linear discriminant analysis 0.1517941786788446
# video retrieval : linear discriminant analysis 0.1776009550180665
# robot control : linear discriminant analysis 0.055691127128067786
# surveillance systems : linear discriminant analysis 0.08164038230320114
# gait recognition : linear discriminant analysis 0.0
# target tracking : linear discriminant analysis 0.0
# === attaching linear discriminant analysis  to  web mining
# supervised machine learning : bayesian classifier 0.4113033349750481
# unsupervised learning : bayesian classifier 0.2492529218604549
# reinforcement learning : bayesian classifier 0.2888040603732853
# document classification : bayesian classifier 0.7534067010891047
# brain-computer interface : bayesian classifier 0.7211380235122293
# spam detection : bayesian classifier 0.16034257743548364
# pattern mining : bayesian classifier 0.167393212074316
# graph mining : bayesian classifier 0.24454243653089958
# web mining : bayesian classifier 0.5650955571247258
# text mining : bayesian classifier 0.5102821287958947
# mobile robotics : bayesian classifier 0.3254289581151393
# web usage mining : bayesian classifier 0.41932048469543326
# rule discovery : bayesian classifier 0.22822960658112024
# microarray experiments : bayesian classifier 0.17390000245488357
# document retrieval : bayesian classifier 0.2932399708654235
# query processing : bayesian classifier 0.0550339224995852
# relevance feedback : bayesian classifier 0.1993979396610533
# query expansion : bayesian classifier 0.24850070044127404
# text clustering : bayesian classifier 0.6257897133317785
# document analysis : bayesian classifier 0.34426961577150506
# video retrieval : bayesian classifier 0.2557412960658122
# robot control : bayesian classifier 0.2161678873899665
# surveillance systems : bayesian classifier 0.22090897530088127
# gait recognition : bayesian classifier 0.07056537144198194
# target tracking : bayesian classifier 0.08113145807839617
# === attaching bayesian classifier  to  document classification
# supervised machine learning : decision trees 0.027015537476732878
# unsupervised learning : decision trees 0.06808123674115885
# reinforcement learning : decision trees 0.14623377656960457
# document classification : decision trees 0.25789612591100936
# brain-computer interface : decision trees 0.1538990631090618
# spam detection : decision trees 0.0026127925817153175
# pattern mining : decision trees 0.0602248420601998
# graph mining : decision trees 0.10094127948349885
# web mining : decision trees 0.36791434033862347
# text mining : decision trees 0.45483686208312674
# mobile robotics : decision trees 0.14434782558434378
# web usage mining : decision trees 0.22528796670569828
# rule discovery : decision trees 0.06981624695370532
# microarray experiments : decision trees 0.06324094346920162
# document retrieval : decision trees 0.1342989083868008
# query processing : decision trees 0.0
# relevance feedback : decision trees 0.0
# query expansion : decision trees 0.10707091705718874
# text clustering : decision trees 0.10556812788027736
# document analysis : decision trees 0.1425639763651687
# video retrieval : decision trees 0.08339897347655845
# robot control : decision trees 0.050392703148679385
# surveillance systems : decision trees 0.09018134277380067
# gait recognition : decision trees 0.0
# target tracking : decision trees 0.0
# === attaching decision trees  to  text mining
# supervised machine learning : naive bayes classifier 0.21161183390095062
# unsupervised learning : naive bayes classifier 0.23184629847483396
# reinforcement learning : naive bayes classifier 0.27952614008325516
# document classification : naive bayes classifier 1.0040341620346593
# brain-computer interface : naive bayes classifier 0.3077252140713693
# spam detection : naive bayes classifier 0.15870884580085942
# pattern mining : naive bayes classifier 0.16280588555995112
# graph mining : naive bayes classifier 0.2549118701336506
# web mining : naive bayes classifier 0.5505630253256526
# text mining : naive bayes classifier 0.7338149718003693
# mobile robotics : naive bayes classifier 0.3154201567620185
# web usage mining : naive bayes classifier 0.40987488303972586
# rule discovery : naive bayes classifier 0.43947218597400484
# microarray experiments : naive bayes classifier 0.17197756373866602
# document retrieval : naive bayes classifier 0.30888330784970763
# query processing : naive bayes classifier 0.04306478091073529
# relevance feedback : naive bayes classifier 0.0993234201304607
# query expansion : naive bayes classifier 0.2654333730184584
# text clustering : naive bayes classifier 0.6303905731610359
# document analysis : naive bayes classifier 0.33414203048131164
# video retrieval : naive bayes classifier 0.24785586925311054
# robot control : naive bayes classifier 0.2029451239517609
# surveillance systems : naive bayes classifier 0.2079661125823653
# gait recognition : naive bayes classifier 0.06522488393449877
# target tracking : naive bayes classifier 0.07316748035049958
# === attaching naive bayes classifier  to  document classification
# supervised machine learning : k nearest neighbors 0.2963026969789011
# unsupervised learning : k nearest neighbors 0.28241570131114624
# reinforcement learning : k nearest neighbors 0.29796560038087583
# document classification : k nearest neighbors 0.8140837408296774
# brain-computer interface : k nearest neighbors 0.3719702073504705
# spam detection : k nearest neighbors 0.239917663096041
# pattern mining : k nearest neighbors 0.26778600111794937
# graph mining : k nearest neighbors 0.33079848791523114
# web mining : k nearest neighbors 0.6107177957257172
# text mining : k nearest neighbors 0.8605705349235723
# mobile robotics : k nearest neighbors 0.3726366965898644
# web usage mining : k nearest neighbors 0.47356146375619135
# rule discovery : k nearest neighbors 0.2863851622365906
# microarray experiments : k nearest neighbors 0.37743990686359086
# document retrieval : k nearest neighbors 0.3415666742440423
# query processing : k nearest neighbors 0.1820223056979671
# relevance feedback : k nearest neighbors 0.15636967162320492
# query expansion : k nearest neighbors 0.5029702465737105
# text clustering : k nearest neighbors 0.3766334600786043
# document analysis : k nearest neighbors 0.4118987303389664
# video retrieval : k nearest neighbors 0.3096455454246787
# robot control : k nearest neighbors 0.26064735638642356
# surveillance systems : k nearest neighbors 0.26701324574847773
# gait recognition : k nearest neighbors 0.12732658989996715
# target tracking : k nearest neighbors 0.15065810420717896
# === attaching k nearest neighbors  to  text mining
# supervised machine learning : classification trees 0.35411585505615734
# unsupervised learning : classification trees 0.16164676348591556
# reinforcement learning : classification trees 0.22488517791122897
# document classification : classification trees 0.37421286195547543
# brain-computer interface : classification trees 0.3140120504038437
# spam detection : classification trees 0.10584170828625827
# pattern mining : classification trees 0.11876563352668512
# graph mining : classification trees 0.21554212249209315
# web mining : classification trees 0.5765056564186191
# text mining : classification trees 0.48516808418046475
# mobile robotics : classification trees 0.32309751321626534
# web usage mining : classification trees 0.4145859069057132
# rule discovery : classification trees 0.17895693708795413
# microarray experiments : classification trees 0.13827667560190304
# document retrieval : classification trees 0.2570048464919805
# query processing : classification trees 0.0
# relevance feedback : classification trees 0.04054920935664452
# query expansion : classification trees 0.20499951399978256
# text clustering : classification trees 0.28930050657372897
# document analysis : classification trees 0.36635423853488724
# video retrieval : classification trees 0.2180176325479628
# robot control : classification trees 0.18615802364346168
# surveillance systems : classification trees 0.1973792569649352
# gait recognition : classification trees 0.0
# target tracking : classification trees 0.010866480226845332
# === attaching classification trees  to  web mining
# supervised machine learning : artificial neural networks 0.0
# unsupervised learning : artificial neural networks 0.0
# reinforcement learning : artificial neural networks 0.0
# document classification : artificial neural networks 0.0
# brain-computer interface : artificial neural networks 0.0
# spam detection : artificial neural networks 0.0
# pattern mining : artificial neural networks 0.0
# graph mining : artificial neural networks 0.0
# web mining : artificial neural networks 0.3382369009971383
# text mining : artificial neural networks 0.17628947426609876
# mobile robotics : artificial neural networks 0.0
# web usage mining : artificial neural networks 0.03696557601729966
# rule discovery : artificial neural networks 0.0
# microarray experiments : artificial neural networks 0.0
# document retrieval : artificial neural networks 0.0
# query processing : artificial neural networks 0.0
# relevance feedback : artificial neural networks 0.0
# query expansion : artificial neural networks 0.0
# text clustering : artificial neural networks 0.0
# document analysis : artificial neural networks 0.0
# video retrieval : artificial neural networks 0.0
# robot control : artificial neural networks 0.0
# surveillance systems : artificial neural networks 0.0
# gait recognition : artificial neural networks 0.0
# target tracking : artificial neural networks 0.0
# === attaching artificial neural networks  to  web mining
# supervised machine learning : ridge regression 0.28788725268725335
# unsupervised learning : ridge regression 0.2717685605801491
# reinforcement learning : ridge regression 0.30770972717945355
# document classification : ridge regression 0.4136751043677547
# brain-computer interface : ridge regression 0.3754801799197176
# spam detection : ridge regression 0.22239156602408094
# pattern mining : ridge regression 0.21651234138502984
# graph mining : ridge regression 0.2989334096167937
# web mining : ridge regression 0.5780570771182477
# text mining : ridge regression 0.5086481647479015
# mobile robotics : ridge regression 0.3725237210778415
# web usage mining : ridge regression 0.4423641647640568
# rule discovery : ridge regression 0.28068920409437603
# microarray experiments : ridge regression 0.19692111185151573
# document retrieval : ridge regression 0.3110733083033326
# query processing : ridge regression 0.06767806916942565
# relevance feedback : ridge regression 0.12044234344758586
# query expansion : ridge regression 0.2720415719836813
# text clustering : ridge regression 0.3599744846551014
# document analysis : ridge regression 0.40756447256391626
# video retrieval : ridge regression 0.5861675217396732
# robot control : ridge regression 0.27276812628230607
# surveillance systems : ridge regression 0.25526952338708764
# gait recognition : ridge regression 0.104081905482446
# target tracking : ridge regression 0.12419601945758463
# === attaching ridge regression  to  video retrieval
# supervised machine learning : multilayer perceptron 0.10836421400252583
# unsupervised learning : multilayer perceptron 0.216035910767858
# reinforcement learning : multilayer perceptron 0.2562163899056571
# document classification : multilayer perceptron 0.23945944401027175
# brain-computer interface : multilayer perceptron 0.3511360530831856
# spam detection : multilayer perceptron 0.08715781174460291
# pattern mining : multilayer perceptron 0.10491069229212546
# graph mining : multilayer perceptron 0.15295443810531406
# web mining : multilayer perceptron 0.5052936185263635
# text mining : multilayer perceptron 0.3512873704167436
# mobile robotics : multilayer perceptron 0.21519688566965378
# web usage mining : multilayer perceptron 0.2620508172262257
# rule discovery : multilayer perceptron 0.12339727431454484
# microarray experiments : multilayer perceptron 0.13059803359903
# document retrieval : multilayer perceptron 0.1838812415276999
# query processing : multilayer perceptron 0.03161884962020678
# relevance feedback : multilayer perceptron 0.06477509933778991
# query expansion : multilayer perceptron 0.15873894164819058
# text clustering : multilayer perceptron 0.17424324708950234
# document analysis : multilayer perceptron 0.21525740453940356
# video retrieval : multilayer perceptron 0.1509510675433935
# robot control : multilayer perceptron 0.1316976342283398
# surveillance systems : multilayer perceptron 0.1453688039440344
# gait recognition : multilayer perceptron 0.07085654960574789
# target tracking : multilayer perceptron 0.07843066531278078
# === attaching multilayer perceptron  to  web mining
# supervised machine learning : maximum entropy 0.13089879265698245
# unsupervised learning : maximum entropy 0.3355880109449413
# reinforcement learning : maximum entropy 0.2542914233732263
# document classification : maximum entropy 0.32150049875988995
# brain-computer interface : maximum entropy 0.26270433837989327
# spam detection : maximum entropy 0.09911570122023061
# pattern mining : maximum entropy 0.12125235254641364
# graph mining : maximum entropy 0.19306308368637248
# web mining : maximum entropy 0.48387247390900345
# text mining : maximum entropy 0.43693955547055163
# mobile robotics : maximum entropy 0.2653701221147421
# web usage mining : maximum entropy 0.33012806660645033
# rule discovery : maximum entropy 0.1550465633645538
# microarray experiments : maximum entropy 0.12443681584192778
# document retrieval : maximum entropy 0.24420265304960076
# query processing : maximum entropy 0.013008721205979845
# relevance feedback : maximum entropy 0.10675926023738048
# query expansion : maximum entropy 0.20635011580387008
# text clustering : maximum entropy 0.24096601237853899
# document analysis : maximum entropy 0.2806947058506408
# video retrieval : maximum entropy 0.19162073878089136
# robot control : maximum entropy 0.1581443660505738
# surveillance systems : maximum entropy 0.1621154552099331
# gait recognition : maximum entropy 0.019379314997922892
# target tracking : maximum entropy 0.06293398379820493
# === attaching maximum entropy  to  web mining
# supervised machine learning : ls-svm 0.11019947850243994
# unsupervised learning : ls-svm 0.1717949356326287
# reinforcement learning : ls-svm 0.33103764450854356
# document classification : ls-svm 0.26232746243041505
# brain-computer interface : ls-svm 0.41773065045643987
# spam detection : ls-svm 0.08600277815967694
# pattern mining : ls-svm 0.10670134257135355
# graph mining : ls-svm 0.16018728440605967
# web mining : ls-svm 0.4034053074706614
# text mining : ls-svm 0.3765078094426699
# mobile robotics : ls-svm 0.22351190847497815
# web usage mining : ls-svm 0.2732298391820811
# rule discovery : ls-svm 0.12901480368688956
# microarray experiments : ls-svm 0.12735671625649347
# document retrieval : ls-svm 0.1945480428017281
# query processing : ls-svm 0.022846509499361733
# relevance feedback : ls-svm 0.06032992278597471
# query expansion : ls-svm 0.1725218716558492
# text clustering : ls-svm 0.1948595052199784
# document analysis : ls-svm 0.22131661844153983
# video retrieval : ls-svm 0.15794198220964972
# robot control : ls-svm 0.13317563276561506
# surveillance systems : ls-svm 0.14561628671810922
# gait recognition : ls-svm 0.030320821659632236
# target tracking : ls-svm 0.040163528563952444
# === attaching ls-svm  to  brain-computer interface
# supervised machine learning : decision tree induction 0.10680391916109033
# unsupervised learning : decision tree induction 0.14206100726383708
# reinforcement learning : decision tree induction 0.21865866733017292
# document classification : decision tree induction 0.3874740230760292
# brain-computer interface : decision tree induction 0.2654436983058419
# spam detection : decision tree induction 0.06088261421533714
# pattern mining : decision tree induction 0.22843809842442378
# graph mining : decision tree induction 0.4606250398065242
# web mining : decision tree induction 0.6054540707682269
# text mining : decision tree induction 0.517211795475142
# mobile robotics : decision tree induction 0.314557321530327
# web usage mining : decision tree induction 0.459650700788957
# rule discovery : decision tree induction 0.3335658792771996
# microarray experiments : decision tree induction 0.10774104473330004
# document retrieval : decision tree induction 0.25213956749564415
# query processing : decision tree induction 0.0
# relevance feedback : decision tree induction 0.015553249856409379
# query expansion : decision tree induction 0.19746729562446852
# text clustering : decision tree induction 0.2926786451143336
# document analysis : decision tree induction 0.3484394523792258
# video retrieval : decision tree induction 0.20993437480059174
# robot control : decision tree induction 0.15787611874045981
# surveillance systems : decision tree induction 0.1683040886605398
# gait recognition : decision tree induction 0.0
# target tracking : decision tree induction 0.0
# === attaching decision tree induction  to  web mining
# supervised machine learning : regression trees 0.19710692134569396
# unsupervised learning : regression trees 0.3575747930004097
# reinforcement learning : regression trees 0.5373253852891713
# document classification : regression trees 0.39728652514697704
# brain-computer interface : regression trees 0.3088439947316457
# spam detection : regression trees 0.14157680193907118
# pattern mining : regression trees 0.15272762998432687
# graph mining : regression trees 0.24729503804147623
# web mining : regression trees 0.5699876562859456
# text mining : regression trees 0.49797827627020497
# mobile robotics : regression trees 0.3305473020668598
# web usage mining : regression trees 0.42780184136497224
# rule discovery : regression trees 0.21709713429408817
# microarray experiments : regression trees 0.14814178754164187
# document retrieval : regression trees 0.2723680229235772
# query processing : regression trees 0.02131244353211592
# relevance feedback : regression trees 0.06781987524535416
# query expansion : regression trees 0.22658499895834994
# text clustering : regression trees 0.31018067267840843
# document analysis : regression trees 0.36620887562550397
# video retrieval : regression trees 0.23594109773175842
# robot control : regression trees 0.22287292323048402
# surveillance systems : regression trees 0.2032810912771994
# gait recognition : regression trees 0.03066045873247558
# target tracking : regression trees 0.047472782732973284
# === attaching regression trees  to  web mining
# supervised machine learning : nearest neighbour 0.26487361896197026
# unsupervised learning : nearest neighbour 0.2553567405036199
# reinforcement learning : nearest neighbour 0.2744955087276999
# document classification : nearest neighbour 0.42908067923490656
# brain-computer interface : nearest neighbour 0.3361528662007711
# spam detection : nearest neighbour 0.1959924993115425
# ...
# === attaching neural network ensemble  to  text mining
# supervised machine learning : markov model 0.2372823952845391
# unsupervised learning : markov model 0.26316090856758256
# reinforcement learning : markov model 0.32906434004048024
# document classification : markov model 0.5796795346033187
# brain-computer interface : markov model 0.346149647428599
# spam detection : markov model 0.21482123217508398
# pattern mining : markov model 0.2254937458759967
# graph mining : markov model 0.2769501979826825
# web mining : markov model 0.9687951573970339
# text mining : markov model 0.4808772940089152
# mobile robotics : markov model 0.36808230550025756
# web usage mining : markov model 1.0198486026041536
# rule discovery : markov model 0.2581468988129765
# microarray experiments : markov model 0.2201505184796949
# document retrieval : markov model 0.2986689703553824
# query processing : markov model 0.08290729192716606
# relevance feedback : markov model 0.12872393186512
# query expansion : markov model 0.2687364880136478
# text clustering : markov model 0.3297621860697857
# document analysis : markov model 0.38485955170874897
# video retrieval : markov model 0.2774340107495257
# robot control : markov model 0.2798811913821958
# surveillance systems : markov model 0.2627696092746612
# gait recognition : markov model 0.11004464757872467
# target tracking : markov model 0.13426079440082883
# === attaching markov model  to  web usage mining
# supervised machine learning : conjugate gradient 0.28090564538402396
# unsupervised learning : conjugate gradient 0.26845028825181916
# reinforcement learning : conjugate gradient 0.5170720507398331
# document classification : conjugate gradient 0.9022212779682907
# brain-computer interface : conjugate gradient 0.40453051169742515
# spam detection : conjugate gradient 0.2307606574239247
# pattern mining : conjugate gradient 0.2246941369813218
# graph mining : conjugate gradient 0.30603847594686107
# web mining : conjugate gradient 0.588709987767744
# text mining : conjugate gradient 0.5121299502218942
# mobile robotics : conjugate gradient 0.40507283536066474
# web usage mining : conjugate gradient 0.4664824170088183
# rule discovery : conjugate gradient 0.3009628864593963
# microarray experiments : conjugate gradient 0.19359450388773158
# document retrieval : conjugate gradient 0.3024638274525492
# query processing : conjugate gradient 0.0735866365029122
# relevance feedback : conjugate gradient 0.11993944050576688
# query expansion : conjugate gradient 0.26220559949835276
# text clustering : conjugate gradient 0.36436468855941384
# document analysis : conjugate gradient 0.969707697070381
# video retrieval : conjugate gradient 0.3040360664073445
# robot control : conjugate gradient 0.31220049877433964
# surveillance systems : conjugate gradient 0.28252973362367007
# gait recognition : conjugate gradient 0.10582678531400291
# target tracking : conjugate gradient 0.13882759176717707
# === attaching conjugate gradient  to  document analysis
# supervised machine learning : quadratic discriminant analysis 0.09333603423392889
# unsupervised learning : quadratic discriminant analysis 0.1222498279566765
# reinforcement learning : quadratic discriminant analysis 0.19976202629754347
# document classification : quadratic discriminant analysis 0.2837962143421764
# brain-computer interface : quadratic discriminant analysis 0.7002381588487948
# spam detection : quadratic discriminant analysis 0.06930164978064834
# pattern mining : quadratic discriminant analysis 0.09481358487320124
# graph mining : quadratic discriminant analysis 0.1772602817873098
# web mining : quadratic discriminant analysis 0.5124209309279129
# text mining : quadratic discriminant analysis 0.4455522955548814
# mobile robotics : quadratic discriminant analysis 0.28429937647493575
# web usage mining : quadratic discriminant analysis 0.3547345175068102
# rule discovery : quadratic discriminant analysis 0.12653814970645705
# microarray experiments : quadratic discriminant analysis 0.1165723606412914
# document retrieval : quadratic discriminant analysis 0.2093766307364332
# query processing : quadratic discriminant analysis 0.0
# relevance feedback : quadratic discriminant analysis 0.023990110577730595
# query expansion : quadratic discriminant analysis 0.17143115786110652
# text clustering : quadratic discriminant analysis 0.22051512979950005
# document analysis : quadratic discriminant analysis 0.32681755121353495
# video retrieval : quadratic discriminant analysis 0.18752985389595267
# robot control : quadratic discriminant analysis 0.14538804488470758
# surveillance systems : quadratic discriminant analysis 0.1739080108495361
# gait recognition : quadratic discriminant analysis 0.0
# target tracking : quadratic discriminant analysis 0.0
# === attaching quadratic discriminant analysis  to  brain-computer interface
# supervised machine learning : least squares support vector machine 0.11248579449450036
# unsupervised learning : least squares support vector machine 0.17547223283338187
# reinforcement learning : least squares support vector machine 0.23517710289390537
# document classification : least squares support vector machine 0.28254093658315305
# brain-computer interface : least squares support vector machine 0.5169052298707207
# spam detection : least squares support vector machine 0.0867649118615974
# pattern mining : least squares support vector machine 0.11109558306360379
# graph mining : least squares support vector machine 0.16878130795717272
# web mining : least squares support vector machine 0.4454505338719008
# text mining : least squares support vector machine 0.4114220678706202
# mobile robotics : least squares support vector machine 0.24300274901113406
# web usage mining : least squares support vector machine 0.29403881046163527
# rule discovery : least squares support vector machine 0.1368407151095783
# microarray experiments : least squares support vector machine 0.12506694377816463
# document retrieval : least squares support vector machine 0.20302522007505386
# query processing : least squares support vector machine 0.01662520640048637
# relevance feedback : least squares support vector machine 0.05587916324395947
# query expansion : least squares support vector machine 0.17604112694859297
# text clustering : least squares support vector machine 0.20948975427755634
# document analysis : least squares support vector machine 0.24786374109999343
# video retrieval : least squares support vector machine 0.17078778455184418
# robot control : least squares support vector machine 0.1380686757617956
# surveillance systems : least squares support vector machine 0.15221006069936505
# gait recognition : least squares support vector machine 0.0232771915071176
# target tracking : least squares support vector machine 0.03512731530750446
# === attaching least squares support vector machine  to  brain-computer interface
# supervised machine learning : statistical pattern recognition 0.0
# unsupervised learning : statistical pattern recognition 0.0
# reinforcement learning : statistical pattern recognition 0.020499213088787105
# document classification : statistical pattern recognition 0.05287668808501689
# brain-computer interface : statistical pattern recognition 0.041628173234759536
# spam detection : statistical pattern recognition 0.0
# pattern mining : statistical pattern recognition 0.0
# graph mining : statistical pattern recognition 0.0
# web mining : statistical pattern recognition 0.4269596158521206
# text mining : statistical pattern recognition 0.34435402545437066
# mobile robotics : statistical pattern recognition 0.05061940977111723
# web usage mining : statistical pattern recognition 0.14872326687871018
# rule discovery : statistical pattern recognition 0.0
# microarray experiments : statistical pattern recognition 0.0
# document retrieval : statistical pattern recognition 0.003561954115661514
# query processing : statistical pattern recognition 0.0
# relevance feedback : statistical pattern recognition 0.0
# query expansion : statistical pattern recognition 0.0
# text clustering : statistical pattern recognition 0.0
# document analysis : statistical pattern recognition 0.0302033442585047
# video retrieval : statistical pattern recognition 0.0
# robot control : statistical pattern recognition 0.0
# surveillance systems : statistical pattern recognition 0.0
# gait recognition : statistical pattern recognition 0.0
# target tracking : statistical pattern recognition 0.0
# === attaching statistical pattern recognition  to  web mining
# supervised machine learning : recursive feature elimination 0.18028853161385372
# unsupervised learning : recursive feature elimination 0.19444348734017447
# reinforcement learning : recursive feature elimination 0.2339028261900804
# document classification : recursive feature elimination 0.37759220835555074
# brain-computer interface : recursive feature elimination 0.3524518107138961
# spam detection : recursive feature elimination 0.13286987407963313
# pattern mining : recursive feature elimination 0.14362803047190797
# graph mining : recursive feature elimination 0.22504308274881935
# web mining : recursive feature elimination 0.5424951994582922
# text mining : recursive feature elimination 0.5138032430145479
# mobile robotics : recursive feature elimination 0.29883164745838076
# web usage mining : recursive feature elimination 0.3852599386043082
# rule discovery : recursive feature elimination 0.19826430716287125
# microarray experiments : recursive feature elimination 0.1516624348162845
# document retrieval : recursive feature elimination 0.27731984997986947
# query processing : recursive feature elimination 0.02578816480557944
# relevance feedback : recursive feature elimination 0.07844462855904966
# query expansion : recursive feature elimination 0.23616813998489716
# text clustering : recursive feature elimination 0.2896357592091703
# document analysis : recursive feature elimination 0.3387762860440444
# video retrieval : recursive feature elimination 0.24295762314288238
# robot control : recursive feature elimination 0.18121985917309014
# surveillance systems : recursive feature elimination 0.2023334281418152
# gait recognition : recursive feature elimination 0.041494313835115926
# target tracking : recursive feature elimination 0.05217251658813249
# === attaching recursive feature elimination  to  web mining
# supervised machine learning : bayes classifier 0.1901037621683731
# unsupervised learning : bayes classifier 0.19489176034936828
# reinforcement learning : bayes classifier 0.25785954809771994
# document classification : bayes classifier 0.6744714998550508
# brain-computer interface : bayes classifier 0.3250196397093723
# spam detection : bayes classifier 0.14900950208007668
# pattern mining : bayes classifier 0.1515476633649968
# graph mining : bayes classifier 0.22967857800341962
# web mining : bayes classifier 0.5125965285656906
# text mining : bayes classifier 0.7582610830193355
# mobile robotics : bayes classifier 0.32179385933046156
# web usage mining : bayes classifier 0.38516722743913534
# rule discovery : bayes classifier 0.19964630068532596
# microarray experiments : bayes classifier 0.15603239150426973
# document retrieval : bayes classifier 0.2546529192173139
# query processing : bayes classifier 0.028578011965211814
# relevance feedback : bayes classifier 0.07353755443170817
# query expansion : bayes classifier 0.22254947316755835
# text clustering : bayes classifier 0.289083949285712
# document analysis : bayes classifier 0.3463537724600272
# video retrieval : bayes classifier 0.22961279724661232
# robot control : bayes classifier 0.2137451501409302
# surveillance systems : bayes classifier 0.20841271385721605
# gait recognition : bayes classifier 0.04199282652644887
# target tracking : bayes classifier 0.061940242113388555
# === attaching bayes classifier  to  text mining
# ROOT  (eid=-1, log_prob=0.000000)
# 	machine learning  (eid=8723, log_prob=0.000000)
# 		supervised machine learning  (eid=15042, log_prob=0.000000)
# 			support vector machines  (eid=15066, log_prob=0.000000)
# 		unsupervised learning  (eid=16106, log_prob=0.000000)
# 		reinforcement learning  (eid=12815, log_prob=0.000000)
# 		document classification  (eid=4127, log_prob=-0.223454)
# 			linear support vector machines  (eid=8369, log_prob=0.000000)
# 			bayesian classifier  (eid=1064, log_prob=-0.014759)
# 			naive bayes classifier  (eid=10023, log_prob=-0.125951)
# 			regularized least squares  (eid=12798, log_prob=-0.245479)
# 			probabilistic neural network  (eid=11942, log_prob=-0.216559)
# 		brain-computer interface  (eid=1480, log_prob=-0.538138)
# 			ls-svm  (eid=8676, log_prob=-0.179577)
# 			quadratic discriminant analysis  (eid=12304, log_prob=-0.352198)
# 			least squares support vector machine  (eid=8194, log_prob=-0.328887)
# 		spam detection  (eid=14394, log_prob=-0.328447)
# 	data mining  (eid=3362, log_prob=0.000000)
# 		pattern mining  (eid=11186, log_prob=0.000000)
# 		graph mining  (eid=6257, log_prob=0.000000)
# 		web mining  (eid=16714, log_prob=0.000000)
# 			naive bayes  (eid=10022, log_prob=0.000000)
# 			k-nearest neighbour  (eid=7816, log_prob=-0.066837)
# 			nearest neighbor  (eid=7819, log_prob=-0.088544)
# 			logistic regression  (eid=8562, log_prob=-0.062026)
# 			linear discriminant analysis  (eid=8335, log_prob=0.000000)
# 			classification trees  (eid=2171, log_prob=-0.150384)
# 			artificial neural networks  (eid=702, log_prob=-0.264328)
# 			multilayer perceptron  (eid=9790, log_prob=-0.164607)
# 			maximum entropy  (eid=9007, log_prob=-0.154741)
# 			decision tree induction  (eid=3493, log_prob=-0.241960)
# 			regression trees  (eid=12781, log_prob=-0.218525)
# 			nearest neighbour  (eid=10114, log_prob=-0.224368)
# 			kernel pca  (eid=7850, log_prob=-0.228640)
# 			neural nets  (eid=10230, log_prob=-0.247640)
# 			support vector regression  (eid=15068, log_prob=-0.282214)
# 			cascade correlation  (eid=1766, log_prob=-0.296218)
# 			bayesian classification  (eid=1063, log_prob=-0.352314)
# 			classification and regression trees  (eid=2164, log_prob=-0.305605)
# 			relevance vector machine  (eid=12892, log_prob=-0.288949)
# 			classifier ensemble  (eid=2175, log_prob=-0.280322)
# 			back-propagation neural network  (eid=929, log_prob=-0.278245)
# 			statistical pattern recognition  (eid=14723, log_prob=-0.457308)
# 			recursive feature elimination  (eid=12703, log_prob=-0.339563)
# 		text mining  (eid=15448, log_prob=0.000000)
# 			neural networks  (eid=10231, log_prob=0.000000)
# 			random forests  (eid=12494, log_prob=0.000000)
# 			decision trees  (eid=3490, log_prob=-0.068937)
# 			k nearest neighbors  (eid=7814, log_prob=-0.100411)
# 			learning vector quantization  (eid=8192, log_prob=-0.229381)
# 			bayesian networks  (eid=1074, log_prob=-0.408027)
# 			ensemble classifier  (eid=4618, log_prob=-0.297656)
# 			self-organizing map  (eid=13627, log_prob=-0.400991)
# 			neural network ensemble  (eid=10237, log_prob=-0.340815)
# 			bayes classifier  (eid=1050, log_prob=-0.323842)
# 		mobile robotics  (eid=9538, log_prob=-0.242318)
# 		web usage mining  (eid=16740, log_prob=-0.236318)
# 			markov model  (eid=8887, log_prob=-0.452442)
# 		rule discovery  (eid=13277, log_prob=-0.304803)
# 		microarray experiments  (eid=9290, log_prob=-0.705413)
# 	information retrieval  (eid=7348, log_prob=0.000000)
# 		document retrieval  (eid=4144, log_prob=0.000000)
# 		query processing  (eid=12403, log_prob=0.000000)
# 		relevance feedback  (eid=12886, log_prob=0.000000)
# 		query expansion  (eid=12388, log_prob=-0.280881)
# 		text clustering  (eid=15437, log_prob=-0.172475)
# 		document analysis  (eid=4125, log_prob=-0.259955)
# 			vector quantization  (eid=16304, log_prob=-0.309817)
# 			conjugate gradient  (eid=2739, log_prob=-0.327873)
# 		video retrieval  (eid=16400, log_prob=-0.292992)
# 			ridge regression  (eid=13108, log_prob=-0.181266)
# 	artificial intelligence  (eid=697, log_prob=0.000000)
# 		robot control  (eid=13164, log_prob=-0.290148)
# 		surveillance systems  (eid=15093, log_prob=-0.412415)
# 	pattern recognition  (eid=11187, log_prob=0.000000)
# 		gait recognition  (eid=5781, log_prob=-0.365563)
# 	computational linguistics  (eid=2603, log_prob=-0.083428)
# 	human-computer interaction  (eid=6928, log_prob=-0.072249)
# 		target tracking  (eid=15257, log_prob=-0.371075)
# 	biomedical research  (eid=1268, log_prob=-0.209034)
